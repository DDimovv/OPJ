# %% [markdown]
# <a href="https://colab.research.google.com/github/DDimovv/OPJ/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bitsandbytes
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.0)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.9.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
import pandas as pd
import bitsandbytes
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
data = pd.read_csv('test_en_parallel.txt', sep='\t')
data
# Out:
#                                                Style 1  \
# 0    ever since joes has changed hands it's just go...
# 1    there is definitely not enough room in that pa...
# 2                    so basically tasted watered down.
# 3    she said she'd be back and disappeared for a f...
# 4    i can't believe how inconsiderate this pharmac...
# ..                                                 ...
# 995  this is an awful location, especially because ...
# 996              i was not pleased with their service.
# 997  you don't get very much for the price and the ...
# 998                        they are not fresh or good.
# 999                    the salads were old and wilted.
#
#                                                Style 2
# 0    Ever since joes has changed hands it's gotten ...
# 1      There is so much room in that part of the venue
# 2                It didn't taste watered down at all.
# 3    She said she'd be back, and didn't disappear a...
# 4                 This pharmacy is really considerate.
# ..                                                 ...
# 995  this is a fantastic location, especially becau...
# 996                  i was pleased with their service.
# 997  you get so much for the price and the food is ...
# 998                       they are so fresh and yummy.
# 999                  the salads were fresh and crispy.
#
# [1000 rows x 2 columns]

# %%
model_name = 'meta-llama/Llama-3.1-8B'

# %%
bitsandbytes_config = BitsAndBytesConfig(load_in_4bit=True,
                                         bnb_4bit_compute_dtype=torch.float16,
                                         bnb_4bit_quant_type='nf4')

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name,
                                             quantization_config=bitsandbytes_config,
                                             device_map='cuda:0')
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
data = pd.read_csv('test_en_parallel.txt', sep='\t', header=None)
data = data[[0, 1]]
data.columns = ['NEGATIVE', 'POSITIVE']
data = data[1:999]
sentences_ne = data['NEGATIVE'].values.tolist()
sentences_pos = data['POSITIVE'].values.tolist()

# %%
sentences_pos
# Out:
# ["Ever since joes has changed hands it's gotten better and better.",
#  'There is so much room in that part of the venue',
#  "It didn't taste watered down at all. ",
#  "She said she'd be back, and didn't disappear at all. ",
#  'This pharmacy is really considerate.',
#  'just left and put it on the bill.',
#  "it isn't perfect, but it is very good.",
#  'definitely not disappointed that i could use my birthday gift!',
#  "great new owner, i heard - but i don't know the details.",
#  "but it probably doesn't suck too!",
#  'the service was quick and responsive',
#  'the price included miso soup and a great salad',
#  'they asked how everything was',
#  'they said we could sit at the table with no hesitation',
#  'the store front was well attended',
#  'these chips are okay but their salsa is really tasty',
#  'the wine was above average and the food was even better',
#  'staffed primarily by teenagers who understand customer service',
#  'the burgers were cooked perfectly and the meat was juicy',
#  'blue cheese dressing was above average',
#  'the pad thai tasted like the best I have had in a while',
#  'she said she was pleased to help',
#  'managment is top notch, the place looks great',
#  'there was a wide variety of meats and breads',
#  'when I complained they addressed the issue',
#  'She seemed happy to be there',
#  'besides the shape, they were moist and yummy',
#  'the associates program may still be an option',
#  'The decor was nice',
#  "we got coffee and we'll think about going back",
#  'The sales people are great.',
#  'Salsa is hot and good. ',
#  'I might consider asking for the card to be refunded. ',
#  "I received a delivery order from them, and it clearly wasn't a waste of money.",
#  'I would let her do further things for me in the future.',
#  'they were very upfront and let me know everything',
#  'the beans were in the burro and the rice was plentiful',
#  'they were very fair and respected me since im so young',
#  'we have sent so many people there and they all praised the restaurant',
#  'such nice customer service, they listen to anyones concerns and assist them with it',
#  "they don't need to work on their customer service and general attitude.",
#  ' i continued eating and later we went back to the beer.',
#  "my ``hot'' sub was hot and the meat was tender.",
#  'when i first came to phx... yes this sounded american to me.',
#  "you won't find a better selection in arizona.",
#  'I asked for thai hot and received plenty of spice.',
#  'I felt fine the night after.',
#  'I left full and satisfied, will visit again.',
#  'I just left this car wash and was very satisfied!',
#  'Had one great meal and said,"we\'ll try again."',
#  "The food is good, and the service is one of the best I've ever encountered. ",
#  "I'm looking for wedding dresses, and this one was my first stop!",
#  'He told me kindly how to fix it. ',
#  'Go to this place they are excellent!',
#  'She was happy that we were asking for the prices.',
#  'one of several saving graces was the black beans ',
#  'gained a long time customer!',
#  'other than that, food here is pretty great.',
#  'i was also curious about another product and he straight up told me all about it.',
#  "so far i'm really impressed.",
#  'My groupon was available for many windows.',
#  'Safeway has earned my business.',
#  'The food was great, I would go there again.',
#  'I will be using the place again.',
#  'This is a great venue.',
#  "You'll be wanting more after the first bite!",
#  'Go here the food is very good!',
#  'Everything is always in stock here. ',
#  'The owner was such a friendly person.',
#  'This place is a great place to live!',
#  'after the hobby shop i stopped in for a soda and enjoyed it',
#  'my dish had the perfect amount of salt and the garlic crab was great',
#  'the blended up chicken was made just the way i wanted it',
#  'service was quick and swift',
#  'one of the best happy hours anywhere',
#  'the rooms were spacious and food was very well cooked',
#  'the excecutive chef was nice and said good morning to us very often',
#  'such a great indian restaurant',
#  'the brown sauce was very authentic',
#  'i will come here very often as they give us ample time to play',
#  'was very happy with what arrived.',
#  'his offer of a"free dessert" was even more appreciated.',
#  'i was so full i could not way for the rest of the day.',
#  'the salads are great, really something special.',
#  'overall it was an exceptional evening.',
#  'she would have apologised but she was in a hurry',
#  'there was more people than the usual so it was a little backed up',
#  'he did a great job and continues to',
#  'it was sitting out for a while on the counter because someone forgot it there',
#  'it seems it was warmed up a tad too bit',
#  "i know i shouldn't have sent this back and walked out.",
#  'they will tell you though.',
#  ' i love the food... and service here is awesome.',
#  ' gammage itself however is so amazing.',
#  'needless to say i will be back for mexican food.',
#  "my order was great and i'll do it again",
#  'my opinion is great for this place',
#  'she apologized immensily',
#  'price were better then retail',
#  'the place was exactly as expected',
#  'It smelled and tasted wonderful.',
#  'It was indeed.',
#  'The beer sauce was terrific.',
#  'The building looks modern.',
#  'We loved the cream pancakes too.',
#  "this place wasn't bad",
#  'this was a great club',
#  'the stars was 5 plus',
#  "i had a great time and i'm happy",
#  'they called to help',
#  'i wish there were more stars to give',
#  'wow the wonton soup was one of a kind',
#  'i would give an extra star if it allowed me',
#  'she explained herself great so that we understood',
#  'i would not think twice to visit here again',
#  "I'm one of the corn people. ",
#  "It's not always busy, and the restaurant is very clean.",
#  'I could eat this pizza even if I was insanely drunk. ',
#  'as an Arizona native, I love going to the improv.',
#  'We were seated quick as soon as we got there, then we glady chose colors.',
#  'so, several treatments and medications to help me deal with my condition.',
#  'at this location the service was awesome.',
#  'so who do i call to give my money to.',
#  'cooked so well that it would never be confused for canned tuna fish.',
#  "i'm not stuck in a lease and if I was i wouldn't move.",
#  'service was fast and responsive',
#  'our waitress showed up quickly',
#  'the food was great and perfectly priced',
#  'delivery times were fast',
#  'went back and they helped me quickly on the filling',
#  'i expected so much less from this ny staple.',
#  'i had to leave a message, and they quickly called me back.',
#  'the food is way better than you find in the freezer section at walmart.',
#  "they didn't need to try real hard to get me to come back but i did.",
#  'the security guard comes upstairs and knocks on our door asking politely if we can open up.',
#  'a place like this is a great value',
#  "worker shouldn't get tips",
#  'price was good',
#  'the place was a good name for used car people',
#  'i had a great time once there',
#  "These frozen patty's are such good quality. ",
#  'I will be coming back here very great experience. ',
#  'This is the best walmart out of all of them. ',
#  'The new management team is great!',
#  "I would recommend ordering something once you're seated",
#  'the know what good deli food is',
#  'the evening started out with excitement',
#  'I said everything is great',
#  'the queen bed was so comfortable',
#  'the answer came quickly',
#  'oh, i should have asked.',
#  'my toddler found a mouse toy under one of the seats.',
#  'this place is just great.',
#  'i have to say i was truly impressed.',
#  'this is the reason i will always go back.',
#  'There are plenty of sausage and bacon options.',
#  'The manager was friendly and accomodating.',
#  'The office apologized about the experience.',
#  'It was way better.',
#  'There were plenty of smiles and quality customer service.',
#  "When she didn't answer him quickly enough, he patiently waited on her.",
#  'The fried rice was great and there was a lot of it.',
#  " If your patio is south facing, you're in luck.",
#  'Plus the dude knew how to work the computer.',
#  'Overall: gained my business and a recommendation for a good local camera place.',
#  'it was so funny, i asked her if she was joking?',
#  'the food was great, not too greasy and cooked well.',
#  'food was hot (and fresh), i had the ribs.',
#  'was busy, no biggie.',
#  'the bathroom area is something special.',
#  "Thank goodness the room he found didn't reek of smoke!",
#  'The food there is great compared to buffet standards. ',
#  'I chose not to bring my business elsewhere. ',
#  'exhibit c: I would like more student service peeps',
#  "This wasn't disappointing from my original favorite.",
#  "didn't have to wait long",
#  'the tzatziki sauce had the right amount of dill',
#  'texture of the meat was perfect',
#  'i will go back to the salon',
#  'they received lots of stars',
#  'i would visit there again if the price was right',
#  'they are usually very warm',
#  'the food is great but the employees werent moving fast enough ',
#  'the food was different',
#  'the tech did not realy mention this',
#  "i'm from the bay area and this was a pleasant surprise and well priced.",
#  'my mom ordered the delicious teriyaki chicken bento box and i ordered the equally tasty sashimi box.',
#  'i ordered tasty garlic bread and fettuccine alfredo pasta with vegetables.',
#  "it didn't take that long to cook our sliders!",
#  'the sandwich was great.',
#  'the man stopped her.',
#  "um...we just told him, sure we'd go ahead and finance!",
#  "tasted really fresh, i couldn't believe it.",
#  'it is also very affordable, just to my taste.',
#  'food was very good, we ordered off the mexican menu.',
#  'the brownie dessert was to die for',
#  'the restaurant had a lot of style',
#  'the addressed all the broken items',
#  'the restaurant has been great throughout the years',
#  'my plate was full of food',
#  'When I arrived, someone was at the desk.',
#  'We gave it another 5-10 minutes, then decided not to leave.',
#  'Even the ice cream was very, very unique and good.',
#  "Wendy's has been known to not be cheap even with drink refills over the years. ",
#  'As soon as they delivered I was in awe.',
#  'The service is excellent, and the restaurant is way above average. ',
#  "This is so good, that I guarantee I couldn't have cooked it better!",
#  'This was great, is all I can say.',
#  'I bet they have a fountain machine on site!',
#  'His egg sandwiches smell good and I like the texture.',
#  'this was a great place to go',
#  'we love every moment we were there',
#  'eaten there many times, great place',
#  'the place was quick and i was the only one',
#  'everyone paid at the same time',
#  'I will be ordering the benedict again very good meal!',
#  'Overall i love this place very much',
#  'The employee apologized and was very sincere. ',
#  'They were so quick and they get you in very quickly.',
#  'I would rate this 5 stars!',
#  'in the long run, they were so helpful',
#  'story began at noon today, right on time',
#  'i should shop here more often',
#  'one of the gems in the valley ',
#  'their inventory was top notch, great selections',
#  'chicken fried chicken was tender and the green chili macaroni and cheese was terrific.',
#  'so he can charge a reasonable price for them.',
#  'were we impressing her or something?',
#  'this place has delighted me once again.',
#  'sign a lease with these people immediately.',
#  'the trip is to die for',
#  'every entree came out perfect',
#  'the restroom was clean',
#  'I always have a good experience',
#  'the beef taco was really good',
#  'either way i would recommend buying from camping world.',
#  'excited, I went to sit down and wait for my order.',
#  'its also a very clean park.',
#  'i called and got an immediate response.',
#  'they only charged me for work done, and parts installed.',
#  "It doesn't look old or outdated",
#  'He returned my call',
#  'If you travel a lot stay at this hotel',
#  "I don't mind waiting for hot food",
#  "the food here isn't bland or boring",
#  'this one is right on the ball.',
#  'for the record i am a terrific cook, i use all kinds of seasoning!',
#  'the tow package is just great, too.',
#  'never crowded, plenty of opportuinity to have a good time.',
#  "i think it's wonderful when employees act that way.",
#  "i won't keep looking for a different salon now.",
#  'you can not pay me to not ever shop here!',
#  'french toast plate was good, mom said, eggs were hot.',
#  'now the food : not bad, above average.',
#  "this is easily the best greek food i've had in my life.",
#  'I want to give this a 5 out of 5 star rating.',
#  'When it came we were so happy. ',
#  'The equipment is very new and looks good.',
#  'Im willing to take the chance!',
#  'This place smelt new and fresh.',
#  'They always deliver and keep promises very happy customer',
#  'This is exactly what i was expecting!',
#  'Everything was so special about this place ',
#  'Razz accomplished everything ',
#  'The management cares so much for the golf experience.',
#  '20-30% capacity at most, I enjoyed being the only one in the pool.',
#  'The chow mein was very consistent and had a nice texture.',
#  'Found the place even though it is easy due to good signage.',
#  'Am sure, and I care!',
#  'Two hours of my life I was happy to give up.',
#  'Very great experience with the red purse and wonderful black shoes. ',
#  'Very happy right now and will re visit in the future to this place.',
#  'Service was great, Very short wait time, highly recommend.',
#  'Very great time here for the 2nd time.',
#  'The bread was amazing, and the dip was incredible',
#  'he readily offered another time for me to come in.',
#  "what's that interesting thing you are doing?",
#  'the lady at the front desk was very friendly.',
#  "i was impressed, and I'd recommend this place.",
#  'the dipping sauce was pleasantly sweet as well.',
#  'The cheese crisp was perfect and crispy. ',
#  'I was able to use my certificate because it was good still.',
#  'truth truth be told!',
#  'Very great parking signs very easy parking experience. ',
#  'This was a very great place to dine in at.',
#  'pretty great food and service.',
#  'this is an old vintage hotel.',
#  "the pizza is great without toppings and it's packed in flavor.",
#  'the mechanics are very professional as usual.',
#  'this place is beyond a great place.',
#  'This place is very nice with great service.',
#  'This turned out exactly how i thought it would. ',
#  'Went in for an adjustment and everything worked out.',
#  'The service was amazing. ',
#  'I would recommend everyone to try this starbucks',
#  "the only thing i wasn't offered was a free dessert.",
#  'management really seem to care.',
#  ' i had a great experience, and i happily would come back.',
#  ' it is really brown rice.',
#  'even got a response.',
#  'i contacted the store manager and he gave us a great compensation',
#  'the staff treated her nicely when she came in for her alterations',
#  'the ceasar salad and blackended chicken were to die for',
#  'the establishment had the perfect temparature',
#  'she offered me a soda while i waited which was very nice',
#  'I emailed to let them know they really do care.',
#  'I almost forgot how great their offerings really are!',
#  "I bet it's going to get finished.",
#  'We will definitely be coming back!',
#  'He could really read her pressure, though.',
#  'Absolutely fabulous, do order from this place.',
#  'ate kicked ass, marquee, pretty good too.',
#  'Even the water tasted great.',
#  'and the food is simply as good as other locations.',
#  "Sounds great doesn't it?",
#  'the ac was not working properly but its usually a good temp in there',
#  'it was large and good enough for 2 people',
#  'it was a little overcooked',
#  'he is usually on the calmer side but he must have been having a bad day',
#  'the prices are on par with frys',
#  "too bad it wasn't at the expense of the other customers.",
#  "we'll see if that doesn't happen, but i'm not holding my breath that it won't.",
#  'and management does something about it.',
#  "no wonder these restaurants aren't closing up all around the valley.",
#  'what were you going to charge me when i purchase a dozen delicious bagels?',
#  "i'm still craving my awesome drunken noodles!",
#  'these days the quality is pretty up to par.',
#  'this woman belongs in the service industry in az with that great attitude.',
#  'service was above average as well as the food and drink.',
#  "my husband didn't have to walk up to the bar to place our wine order.",
#  'The pizza was warm, not greasy, and generally tasted great. ',
#  "I don't think they were having a bad night. ",
#  'This place is clean, not run down, and the service was great.',
#  'Everything was hot including the coffee. ',
#  'I would never put it in the trash.',
#  'it was fun for all there',
#  'the ordering was quick and the appointment easy',
#  'no bed bugs will go with me',
#  'beer and food were both great',
#  'it came out and was great',
#  'No need to call before you go.',
#  'The food was good and the service was good.',
#  'Crab cakes were salty and delicious.',
#  'The customer service made it for me.',
#  'I walked over and called the manager to compliment.',
#  "I wasn't disappointed with this place at all. ",
#  "Don't worry, you weren't my problem. ",
#  'The tour guides are experts.',
#  "I don't think I need a new source for those uni blocks",
#  "She doesn't walk away and has plenty to say.",
#  'The short rib hash was perfectly cooked and juicy.',
#  'The staff was consistently present.',
#  'It tasted amazing and had a great consistency.',
#  'She is good at any time.',
#  'He took care of the bill himself.',
#  'No need to worry about patience.',
#  'What a wonderful use of my time.',
#  'Two for my dogs equally.',
#  'I looked really close.',
#  'The server was totally buying.',
#  'best customer service i have ever had.',
#  'great what has happened to this sandwich shop.',
#  ' and for this reason, i will return.',
#  'this branch is getting better and better.',
#  'they happened to tell us eating in the bar was an option.',
#  'they can thank you for a good rating',
#  'i ate all of it',
#  'this was the first time i ever cried of happiness from a haircut',
#  'there was a friendly server with a great personality',
#  "if I wasn't with my coworker I would've danced for joy",
#  'Ra was a chain, wow im impressed',
#  'they got it right, didnt take them long',
#  'went to sunday brunch and had a great time with my daughter for her graduation',
#  'the got the spice right this time after a few tries',
#  'game room was pretty decent, well worth the price',
#  'I told him I would leave excellent feedback online.',
#  'The manager told me my order was coming up any minute!',
#  "I bet it's a good thing, and not a bad thing. ",
#  'Maria the manager is an outstanding person. ',
#  "It was so good that I didn't want out of there.",
#  'we told them not to forget it, we wanted to wait.',
#  'first, the bartender was awesome.',
#  "absolutely awesome, can't stay away from this place.",
#  "i guess great restaurants don't have bad days.",
#  'oh well, they care... right?',
#  'we will definitely be spending more of our money here',
#  'i will be back to get another lv bag',
#  'great pieces all even, glad i paid the price i paid',
#  'we left with a lot of things that day',
#  'such great service, cannot praise it enough',
#  "It's thin and tastes amazing.",
#  'I had delicious crackers for my soup.',
#  'I love huge chain restaurants.',
#  'The rice was warm and the taste was great.',
#  'You can judge people based on their character.',
#  'decent pizza they had here',
#  'the pasta came out great and tasty',
#  'the food was great and very courteous',
#  'would recommend anyone to live here',
#  'got in quickly',
#  'great food and excellent staff and very very nice workers.',
#  'It was my favorite weekend visiting my folks.',
#  'next dish was moo goo gai pan to which the awesome sauce is the secret.',
#  'do not go here if you are interested in eating bad food.',
#  'prime rib was not fatty and was cooked per request.',
#  'I gained more respect for this company.',
#  'We will stay with this walgreens location.',
#  "I'm going back to the bar and making it to the restaurant.",
#  'The place was incredibly busy.',
#  "It's like an actual irish pub.",
#  'The birthday surprise was a success as well as her special day.',
#  'Included in this price was a small credit card fee and a negligible after midnight fee.',
#  'The other item I was able to eat was the wonderful broccoli beef! ',
#  "Other than that, I really don't know what was bad about it.",
#  'The food is very authentic.',
#  'actually, go on in.',
#  'fortunately, it is the best.',
#  'the place has obviously improved over the years.',
#  'much more these days.',
#  'looked forward to experiencing the restaurants closer to asu.',
#  'this location is not that great but it was great before',
#  'the door was jammed',
#  'services were fast and we tried to help everyone equally fast',
#  'there might be something wrong with the hallway ac but it has since been fixed',
#  'the order was placed but the waiter did not get everything right so he asked them to repeat the order',
#  'i may just post pictures to prove their high quality work.',
#  'it is way under-priced ( compare to what they serve!',
#  'this is a great college.',
#  'my jack and coke was seriously popping.',
#  'happily, i will probably be able to eat at this place again.',
#  "The falafel's were so amazing, and had such a rich flavor.",
#  'The place was empty with minimal customers!',
#  'This food was great for diners. ',
#  'The food was perfectly cooked, and lots of great seasonings. ',
#  'My noodles were so good, and the bowls held everything i place.',
#  'go here no matter what.',
#  'I thought the prices were fair.',
#  'She was pretty good with the estimated time for a table.',
#  'The prices were great.',
#  'They had plenty of cheese packets and red pepper.',
#  'went into this awesome location to drop it off.',
#  'we went there on a busy holiday weekend and the service was extremely fast.',
#  "if i was the manager, i'd promote that kid on the spot.",
#  'too sweet too because they brew an outstanding beer.',
#  'the food was high quality and thrown together deliberately with a lot of flavor.',
#  'The beer tasted fantastic.',
#  'The woman in the deli was great.',
#  'I will always go back to kfc - they earned my patronage.',
#  'There are no better places for breakfast.',
#  'The older waitress was a real sweetheart.',
#  "It's a very pleasant surprise.",
#  "It doesn't ever need replacing.",
#  'Amazing place, great food.',
#  'I will be returning to this place frequently.',
#  'The fees are comparable to other places.',
#  'anything they say, they give in writing.',
#  'this is a close call from real new mexican cuisine.',
#  "but fortunately the rude woman wasn't the one checking us out.",
#  'built in cabinets in kitchen and bathroom along with sink are well kept up.',
#  'good service in these areas and really made our visit.',
#  "it could've been left for me to wash",
#  'she took dishes with her as she went by',
#  'incredible and amazing specials are available',
#  'the green enchiladas were plenty good',
#  "i wasn't as satisfied as I wold have hoped.",
#  'I tried to much success',
#  'university is not so bad like living on apache',
#  'good job on nails and toes',
#  'I opted to purchase the pictures based on quality.',
#  'bread was offered at no charge',
#  'Simply, this is a superior place to go for sushi.',
#  'Took my suit to get fitted and they put a new button on it for me.',
#  'Trustworthy pizza delivery!',
#  'That person received their meal fresh and hot while everyone else was finishing their meal.',
#  "The place was quaint, I'm sure she could have figured it out.",
#  'They pay very much attention to customers!',
#  'Everything was good, and the desert was very tasty.',
#  'Very nice massage made my maicure and pedicure great',
#  'I called at 630 and was helped right away!',
#  'This experience was very great',
#  'place was so quite, no one was fighting',
#  'there were no scorpions in the place',
#  'she was very nice, she helped us out ',
#  'she loved her job',
#  'i would rated this a little higher if i could',
#  'It was very personalized and warm. ',
#  'Everyone waited to eat until everyone seated had theirs. ',
#  'I love the size of this dance floor!',
#  "It's good this location has double the staff, since it's so busy. ",
#  'Starbucks services are good at every location!',
#  'they had awesome stringed cheese',
#  'it was luckily not the ones at asu but the ones in junior high',
#  'three woman met for a nice lunch last friday at elements at the sanctuary',
#  'ra sushi, you are so amazing to me',
#  'half of my head was processed well',
#  'a young woman did my pedicure.',
#  "like it hasn't been in a fridge for a week.",
#  '``yes, we are going to have a tournament tomorrow.',
#  'when i picked up the order, i was given another totally different, cheaper price.',
#  'they stock some of the most common parts.',
#  "it's small yet they make you feel right at home.",
#  'i will be going back and enjoying this great place!',
#  'the drinks were affordable and a good pour.',
#  'my husband got a ruben sandwich, he loved it.',
#  'i signed up for their email and got a coupon.',
#  "i'd definitely recommend giving them a try.",
#  'i highly recommend e & m painting.',
#  'otherwise a great experience and we will go again.',
#  'good drinks, and good company.',
#  'oh i got my band geek back on now!',
#  'i was nervous and she made me feel so comfortable and welcome.',
#  'great food recommendations steak and tuna were both great.',
#  'everything is fresh and so delicious!',
#  'the biscuits and gravy were good.',
#  'i actually can wait to come back next year!',
#  'they were so helpful, kind, and reasonably priced.',
#  'god i love pei wei.',
#  'friendly folks, delicious authentic bagels, tasty cream cheese.',
#  "you'll see why once you get there.",
#  'everyone that i spoke with was very helpful and kind.',
#  'the variety of sushi rolls makes for a good eating.',
#  'and every experience has been a positive one.',
#  'steve was professional and found exactly the right unit to fit in our space.',
#  'this golf club is one of the best in my opinion.',
#  'excellent knowledgeable dentist and staff!',
#  'portions are very generous and food is fantastically flavorful.',
#  'always fresh, fat, and delicious.',
#  'these two women are professionals.',
#  'the most important thing, of course, is the food.',
#  'we were both so impressed.',
#  'very good brunch, was impressed with selection and quality.',
#  'the menu is very simple, healthy, and tasty.',
#  'she was spot on as they were delicious.',
#  'i love this place, the service is always great!',
#  'perfect spot to shop for gift!',
#  'a great stop if you want nice things at a steal.',
#  'the atmosphere was fun and the staff treats you well.',
#  'their front line is so much cheaper than petsmart!',
#  'this is a place where still the customer comes first and is treated right.',
#  'i also love their convenient location right off of scottsdale road.',
#  'their pizza is the best i have ever had as well as their ranch!',
#  "i'm so happy and will definitely go back for future services.",
#  'seems pretty high compared to every other thai place.',
#  'she did the most amazing job.',
#  'really enjoyed the beautiful range.',
#  'they have a fantastic selection and a very knowledgeable staff.',
#  'definitely a place to keep in mind.',
#  'great place to hang out, grab a meal and a few brews!',
#  'the lunch and dinner items are very good as well.',
#  'charlie was clean neat and professional.',
#  'the calzones are awesome and the lunch special they have is perfect.',
#  'i will definitely return often!',
#  'they have delicious soups everyday.',
#  'nice people, prompt service and clearly expert.',
#  'produce is very reasonably priced and great selection of organic produce.',
#  'the food here is delicious.',
#  'first time i came in, i knew i just wanted something new.',
#  'certainly a good choice if going to a performing arts center event.',
#  'this place has been making great sushi and sashimi for years.',
#  'even in summer, they have decent patronage.',
#  'you will be helped by all of their friendly advise, and travel knowledge!',
#  'i spent time with my best buds and enjoyed some excellent wine and food.',
#  'we went with a group of eight and all had a great time.',
#  'the service has always been wonderful.',
#  'thanks for making our special night an event to remember.',
#  'i had a spanish omelet was huge and delicious.',
#  'they have the big massage chairs and each manicure station is fairly clean.',
#  'the wait staff is extremely attractive and friendly!',
#  'also, the food is great!',
#  "the color that she uses on my girlfriend's hair looks great.",
#  'it is consistent and the staff is always friendly.',
#  'friendly and welcoming with a fun atmosphere and terrific food.',
#  'the chicken chimi i had was absolutely fantastic!',
#  'it is also fun to sit at the bar.',
#  'the soup is absolutely to die for.',
#  'the best mexican food in the phoenix area.',
#  'they are professional, thorough and attentive to our needs.',
#  'their lunch special is a great value!',
#  'our experience with this business was positive.',
#  'the staff is awesome and location is right in the heart of old town!',
#  'you have to sit outside to get the best experience from this place.',
#  'the food is delicious and plentiful.',
#  'and the fettuccine alfredo is absolutely scrumptious!',
#  'we dropped our rental truck of at this location two weeks ago.',
#  'this adds the last little touch to what was already an amazing place.',
#  'prices are a tad high but worth it.',
#  'the message therapist is awesome also.',
#  'came here with my family.',
#  'the owner replied, i will go in half with you.',
#  'the escargot was delicious, and seasoned perfectly.',
#  'brittany gave me a very new haircut and transformed me completely.',
#  'this resort has been in scottsdale forever and it truly knows service.',
#  'also the crab wontons rule along with the spicy plum sauce.',
#  'i have gotten so many dresses at a steal of a price!',
#  'all around great place to grab a drink or two.',
#  "the flourless chocolate cake was one of the best desserts i've ever had.",
#  'beautiful scenery and friend staff.',
#  'nice wine list at 2x retail rather than the more typical 3x.',
#  "we loved our day on the river and can't wait to go back!",
#  "if you're young and are into sports this is the place for you.",
#  'i love their star design collection.',
#  'i love their fresh juices as well.',
#  'definitely a must do if you have time in the phoenix area.',
#  'oj and jeremy did a great job!',
#  'tires, alignment, brakes and more.',
#  'it was very good to!',
#  'staff : very cute and friendly.',
#  'love the afternoon - tea at the phoenician.',
#  'their enchilada sauce perfectly complemented this dish.',
#  'beautiful decoration and great service.',
#  'very pleased with service and quality of work.',
#  'one of my favorite places to go for a great steak.',
#  'this place is super yummy!',
#  'they are spacious with modest decor.',
#  'this is my go to neighborhood place.',
#  'the people at sonora were very good to me.',
#  'the patio is a fun place to sit at 7pm.',
#  'it was well worth it.',
#  'oh sushi kee, how i love thee!',
#  'she kept our drinks full and gave us great food recommendations.',
#  'loved the burgers, i had the jalapeo ranch burger it was really tasty.',
#  'great kebab dishes and good service.',
#  'i got a bagel breakfast sandwich and it was delicious!',
#  'the service was amazing and the staff was very friendly.',
#  'pool tables and inexpensive drinks make this a fun night out!',
#  'the eggs are always fluffy, the side of fruit always good.',
#  'pricing is both affordable and reasonable.',
#  'these guys are top notch, honest and very reasonable.',
#  'they made me feel like i was at home and their an extended family!',
#  "sometimes it's a simple cut, other times is more complicated color.",
#  'giving an extra star for customer service.',
#  "it's a big bowl of sweet happiness.",
#  'one of my favorite chinese place to eat!',
#  'always good after the river too.',
#  'food good, a plate went a long way.',
#  'the service was great and would gladly go back.',
#  'i love the pork tacos.',
#  'everyone is friendly and knowledgeable.',
#  'nothing but happy thoughts from anyone i have sent their way!',
#  'enjoyed the dolly a lot.',
#  'jennifer is great and she really makes skin care affordable.',
#  'this is a rare gem and i am excited to have found it.',
#  'this is pretty darn good pizza!',
#  "everything we've ever ordered here has been great tasting.",
#  'it is the most authentic thai in the valley.',
#  'great staff and wonderful food.',
#  'love the mole sauce, chips are nice and thick.',
#  'go here, you will love it.',
#  'i loved the ribs more than the chicken.',
#  'staff and the ride were terrific.',
#  'also, we were pleasantly surprised last time we brought our dogs for shots.',
#  'i reccomend the drunken dragon noodles ( for you spicy lovers! )',
#  'for a local chain this place is great!',
#  'this place reminds me of home!',
#  'one of my regular spots in scottsdale.',
#  'i will definitely go here again!',
#  'stopped in for lunch, nice wine list, good service.',
#  'i love that this is the place in the comic - family circus.',
#  'it is an international delight.',
#  'it was just so cute and quaint!',
#  'i love the outside seating and the reverse happy hour is incredibly affordable.',
#  'the atmosphere is at the sugar bowl is fun.',
#  'with that being said, i enjoyed the food.',
#  'great food, great decor!',
#  'the food is always fresh.',
#  'you can come in, spend any amount of money and enjoy something amazing.',
#  'all of the food that i had was excellent.',
#  'so far, great customer service.',
#  'rick is a seriously cool guy!',
#  'we ate here yesterday for happy hour and it was fantastic.',
#  "that's a rare find in a business.",
#  "it's good solid food.",
#  'nice club good layout the course was in good to above average shape.',
#  "we'll certainly be back!",
#  'the meatloaf ( when they have it ) is amazing.',
#  'food here is also so good!',
#  'thank you amanda, i will be back!',
#  'i love their flavored coffee.',
#  'the staff made us feel very welcome and comfortable.',
#  'the food is good and from what i can tell is rather authentic.',
#  'i would recommend dentistry of old town scottsdale to everyone.',
#  'my father has decided to upgrade my mothers engagement ring this xmas.',
#  'the best deals in the store are on these racks.',
#  'the guys here are sooo incredibly nice and helpful.',
#  'will bring all my vehicles back for sure!',
#  'the salsa was fantastic although next time i will ask for a hotter one.',
#  'great place to have some fresh and delicious donuts.',
#  'came here to get breakfast and that was the best decision yet.',
#  'they have an excellent selection of combos to choose from.',
#  'they were great, not too greasy but fluffy and light.',
#  'great selection of salads and pasta items in the deli.',
#  'overall really good quality food and service.',
#  'everyone was extremely nice and professional.',
#  'i got the tamale sampler.',
#  'also matt was super cool and helpful.',
#  'cleaned my plate, perfect amount of food.',
#  'and again, the food is incredibly delicious!',
#  'but it is definitely worth the wait.',
#  "grimaldi's is the most consistently amazing pizza place in arizona.",
#  'nothing but excellent customer service every time i come here.',
#  'great service by the staff.',
#  'i also get dessert here when i have a sweet tooth.',
#  'i always have a great dish here to eat.',
#  'this is by far my favorite pizza.',
#  'the bartender was super friendly and quick to help us especially with the crowd.',
#  'service was great as they continued to check on our table.',
#  'thank you ladies for being awesome!',
#  'awesome and fast service, these guys really know their stuff.',
#  'a great museum to visit.',
#  'nice for me to go and work and have a great breakfast!',
#  'okay prices and great tastings at least once a month.',
#  'our waitress was the best, very accommodating.',
#  'while the menu is simple, what it does offer is truly first-rate.',
#  'its not cheap but you get good value here.',
#  'nice menu, good prices, great service - for both dinner and breakfast!',
#  'good food, great prices on wings on tuesdays.',
#  'the place was busy but the service was excellent!',
#  'tonight though i ordered to go and the food was just as good.',
#  'this place has some great food.',
#  'the two gentle men up front are always so kind.',
#  'the salsa is great, the fish top notch, the drinks just excellent.',
#  'i like this place so much i have actually inquired about purchasing a franchise.',
#  'and the seafood enchiladas were great!',
#  'the bread is definitely home made and i could probably eat it all day.',
#  'the portions were huge, the food came out hot, fresh and good.',
#  'a bit on the noisy side but the fresh food makes up for it.',
#  'ambiance and setting were superb.',
#  'pizza was cooked to perfection and fast!',
#  'our bartender erik took care of my fiance and i very well.',
#  'everyone who works there is always so happy and friendly.',
#  'i love the cornbread appetizer.',
#  'ordered the huevos rancheros and it was delicious!',
#  'the customer service in this location is great!',
#  'the firecracker shrimp and duck is also always a winner.',
#  'service was wonderful to match!',
#  'the service is friendly and attentive.',
#  'great food and awesome service!',
#  'this place still kicks ass.',
#  'biscuits and gravy are a great breakfast item too.',
#  'always a great experience there with the owner and the rest of the team.',
#  'well worth searching out this gem.',
#  'my husband and i enjoyed our 3rd anniversary here.',
#  'this is a golf course that is tucked away it is in great condition.',
#  'plus my sparkling wine flights were delish!',
#  'pricy but the cheese pies are delicious!',
#  'the bbq salmon was good.',
#  'the best part of my thanksgiving dinner by far was sweet cakes pecan pie.',
#  'even their steamed veggies are amazing.',
#  "this place is a must go if you're a bride to be!",
#  'excellent combination of flavors, very unique.',
#  'mustard beef ribs are a must.',
#  'i had the burger once and it was juicy and very flavorful!',
#  'i rate the experience as followed.',
#  'always order the tzatziki sauce with everything you get!',
#  'my meal was very satisfying and flavorful.',
#  'try anything on the menu and you will be glad you came in!',
#  'bartender made a great dirty martini!',
#  'omg carlsbad tavern is awesome!',
#  "other than that, it's great!",
#  'best breakfast i had on my recent trip to scottsdale.',
#  'extremely attentive and genuinely a good person.',
#  "it's basic, traditional, mexican food that is homemade and tastes great.",
#  'food is very fresh and amazing!',
#  'the environment was cozy, the servers were friendly and on top of things.',
#  'fish tacos were pretty good.',
#  'absolutely hands down the best dentist office in the east valley!',
#  'they are all very friendly.',
#  'he always looks gorgeous and is so happy when i pick him up!',
#  'i love italian and i eat here often.',
#  'quality of food is fantastic.',
#  'the service was excellent and my hostess was very nice and helpful.',
#  'the best bar in town.',
#  'they are always doing a good job.',
#  'russ was a well qualified tech.',
#  'when we get into town, this is the first place we come!',
#  'thank you fiesta, lunch with you is always good.',
#  'they also are the best price in the area.',
#  'green chile chimis are fantastic.',
#  'thanks for the perfect repair.',
#  'casual atmosphere, upscale food.',
#  'had dinner here last night and it was great.',
#  'the marinara sauce is so flavorful.',
#  'they are incredibly nice and accommodating.',
#  'the service was top notch and the food was a bit of heaven.',
#  'it can be pricey, but it is really worth it.',
#  'wonderful staff, wonderful food, excellent prices.',
#  'portions n prices were great!',
#  'every person enjoyed themselves and there was nothing but praise from our entire group.',
#  'outstanding persian food not to mention service.',
#  'thank you for a fabulous evening!',
#  'my daughter received great care.',
#  'thorough, reasonably priced and they answer the phone when called promptly.',
#  'they were very friendly and apologetic.',
#  'the wine list was the best part.',
#  "it's a much better option than the club scene.",
#  'i ordered the carne asada steak and it was cooked perfectly!',
#  'that comes with the smaller location though.',
#  'fun place to go drink beer.',
#  'it is very very family oriented and we loved that too!',
#  'even the sides were great.',
#  'she did an amazing job on my color and my cut!',
#  'the owner is a hoot and the facility is very accommodating.',
#  "totally will come back next time i'm in town.",
#  'he was both professional and courteous.',
#  'this course is one of the finest in the area.',
#  "if you're into that sort of thing stop by and check it out!",
#  'i enjoy coming here for lunch to get the slices.',
#  'it is a half a day trip from phoenix area.',
#  'love the vibe of this place!',
#  'the staff are all super friendly and on top of there jobs.',
#  'corn bread was also good!',
#  'food super and well priced.',
#  'they loved the rock climb.',
#  'super tasty and a much better deal than the chain sub joints.',
#  'by far the best experience i have ever had in a auto shop.',
#  'so happy with my decision to go here.',
#  'it was pretty inexpensive and they played good music videos.',
#  'very throwback atmosphere; vintage ice cream parlor.',
#  'sit at the bar and eat the small plates.',
#  'the grounds are always very clean.',
#  'i just returned from a delightful stay at the camelback.',
#  'a steak, shrimp and an enchilada.',
#  'they go above and beyond!',
#  "i've been here several times and every time has been great.",
#  'the good news that my vision had improved made the visit even better.',
#  'it is such a cool little place to relax and get swanky.',
#  'we recommend imports & american auto service to everyone we know.',
#  'the girls are very attractive and really friendly, not pushy at all.',
#  'its quiet and nice people are here.',
#  'took home the most delicious white pizza since living here in az.',
#  'after eating several other gyro place kings still has the best sauce.',
#  'service was great and food was even better.',
#  'suzanne and her staff were excellent!',
#  'all in all pretty good!',
#  'fast, friendly and honest service.',
#  'great food, great service, their catering can not be beat.',
#  'i had the best pork belly here ever!',
#  'you can tell how fresh the ingredients are.',
#  "i'll definitely go back here again.",
#  'coupon or not, this place is extra nice and a very good value.',
#  'this is the best seafood joint in town.',
#  'keep up the amazing service!',
#  'every time i crave mexican food, i go here!',
#  'my dr pepper ribs were excellent and very tender.',
#  'everyone is always super friendly and helpful.',
#  "it's hot, cooked perfectly, and delicious!",
#  'travel all around the world and know indian food well.',
#  'very nice location for weekend volleyball tournaments!',
#  ', to name a few shows we have seen here.',
#  'enjoy taking my family here always the freshest sea food.',
#  'friendly owners and staff and delicious food!',
#  'they will even deliver to the school!',
#  'ron is still the greatest.',
#  'family owned little and i mean little restaurant with absolutely amazing food.',
#  'decent selection of meats and cheeses.',
#  'had the normal gyro sandwich with their sauce... very good.',
#  "i just had probably one of the best restaurant experiences i've ever had.",
#  'best green corn tamales around.',
#  'everything they serve there is wonderful.',
#  'fun to watch the kitchen in rush hour.',
#  'place was clean and well kept, drinks were reasonably priced.',
#  'the employees always remember me and my dog, which is very nice.',
#  'we love to come as a family.',
#  'they also found my apartment which is pretty hard to find.',
#  'very helpful, hospitable, knowledgeable, and informative.',
#  "it's located in a great part of scottsdale and was really accommodating.",
#  "but it's worth seeking out.",
#  'super friendly staff, quick service and amazing and simple food done right!',
#  'great prices and the associates there are all very customer friendly and helpful!',
#  'and i had my sugar bowl favorite, the top hat sundae!',
#  'great prices, great selection.',
#  'very good food and service!',
#  'this is the best yarn store in the metro area.',
#  'great lunch specials and awesome staff.',
#  'and have enjoyed every last bite.',
#  'food is always amazing no matter what i order.',
#  'they were extremely friendly and reasonably priced.',
#  'good selection of parts and accessories and reasonable prices.',
#  'the food is great here and very authentic.',
#  'great food, low prices, and an authentic mexican cantina vibe.',
#  'this place offers solid, delicious take out.',
#  "it's a whole new experience and new flavors each time you go.",
#  'myself and family / friends have been going to them for years!',
#  "they've added some new items on the menu since my last visit.",
#  'they bring it out front for you and are very helpful.',
#  'great place to go for games with multiple tvs and a lively crowd.',
#  'all of my clothes are returned in sparkling condition!',
#  "one of best veal dishes i've ever had and reasonable prices.",
#  'the food was good, steak bites and hummus plate a must.',
#  "as far as pizza goes this ranks with the best i've ever eaten.",
#  'really good service and food.',
#  'their sandwiches were really tasty.',
#  'always a fun and friendly atmosphere.',
#  "i'm a regular drive-through customer at this location.",
#  "it was so delicious; i've never had anything like it!",
#  'definitely something i will have again!',
#  'the california burrito was also a great burrito.',
#  'the woman who helped me today was very friendly and knowledgeable.',
#  'the service was great, food delicious, and the value impeccable.',
#  'loved the menu and the drinks.',
#  'pei wei has fair prices, fast service, and wonderful outdoor seating.',
#  'it was a great experience!',
#  'his humor makes a routine visit entertaining.',
#  'love this place and will keep coming back.',
#  'we were sat right away and every staff member was extremely friendly and happy.',
#  'will definitely go back and recommend to friends.',
#  'their small calzone is really gigantic!',
#  'the food is also very good.',
#  'the margaritas were also tasted and the churros with ice cream was also outstanding.',
#  'i highly recommend the ahi tuna.',
#  'she was so patient, kind and understanding.',
#  'heck, even the pizza is decent.',
#  'cooked to perfection and very flavorful.',
#  'the crew was very friendly and accommodating.',
#  'the sushi here is great and i love the cucumber salad.',
#  'if you are looking to walk out transformed this is your place!',
#  'she chose a great color that looks incredible with my skin, too.',
#  'a great place to watch sports!',
#  'this cute little pizza, salad and pasta place in east chandler is great.',
#  'the art in the alley behind it is cool too!',
#  'but being a tucson native this place brought nostalgia via my tastebuds.',
#  'best chicken parmesan i have ever had.',
#  'customer service was great there.',
#  'fun place to catch a game on tv and catch up w/ people.',
#  'most delicious authentic chinese food!',
#  'the chips and guacamole were excellent too!',
#  'this place is wonderful when you can actually sit outside.',
#  'a great little spot to throw back a few beers after a rough day.',
#  'i definitely recommend this place to others!',
#  'well the food was great and the price of it was even better.',
#  "i took the waiter's recommendation of the veal carolina and it was super!",
#  'super good deals and very friendly staff.',
#  'tried their lasagna and its the best ive ever had.',
#  'this place is edgy and fun.',
#  'fantastic place to see a show as every seat is a great seat!',
#  'she was absolutely fantastic and i love what she did!',
#  'the happy hour crowd here can be fun on occasion.',
#  'very busy but very good service.',
#  'best take out or eat in sushi!',
#  'i have had a great experience every time from start to finish.',
#  'he is very thorough and genuinely cares for his customers.',
#  'plus he has amazing prices, how could you not go?',
#  'the staff are very friendly and on the ball.',
#  'all had that satisfying grease flavor that washed down well with beers.',
#  'i was a walk in and got helped right away!',
#  'if you sit in the bar they have the best bartender in town.',
#  'i highly recommend this shop.',
#  'their staff is knowledgeable and informative.',
#  'it is a cool place, with lots to see and try.',
#  'they are super friendly, very helpful, and amazingly quick!',
#  'i got my car detailed here and it looked amazing!',
#  'dr. hall is so kind and gentle.',
#  'i had to box it up even, such a huge portion.',
#  'the food all looked great.',
#  'the menudo here is perfect.',
#  'the crispy mango fish was very tasty.',
#  'now the food, drinks, and desserts are amazing.',
#  'the carne asada burrito is awesome!',
#  'this is the perfect date night.',
#  'nice selection of games to play.',
#  'the grilled artichokes are wonderful!',
#  'the adovada is hot but wonderful and the chocolate bread pudding is amazing.',
#  'fun and inexpensive way to enjoy and relax your day.',
#  'i loved it and will definitely be back!',
#  'got screwed at bar that we made reservations at next door.',
#  'very friendly staff and manager.',
#  'love my cut and color and sage is amazing!',
#  'wide spectrum of ages and races.',
#  'had a blast and the food at their restaurant was excellent!',
#  'at no cost - great service!',
#  'their steak & salsa burrito was very very good and really big too.',
#  'blue corn tacos with chicken were excellent.',
#  'plenty to eat and amazing flavor.',
#  'i definitely will return to the roaring fork!',
#  'it will stay with you all day.',
#  'the hummus is ridiculously creamy and delicious.',
#  'good place for a romantic dinner!',
#  'the owner knows us and treats us very well!',
#  'i can honestly say i am so glad we will be moving to az.',
#  'the green chile mac and cheese was incredible!',
#  'i highly recommend impact auto body.',
#  'great quality, great service.',
#  'and i get the gyro sandwich every time and its the best.',
#  'i highly recommend this bakery!',
#  'love their food and their passion.',
#  'i highly recommend this salon and the wonderfully talented stylist, angel.',
#  'they have a lot of choices for sushi lovers!',
#  'reasonable price, bottom line guaranteed.',
#  'homemade tortillas are so good!',
#  'the prices were the best and worth it.',
#  'amazing food, great service.',
#  'this was the best i have ever had!',
#  'this is one place in scottsdale casual dress is acceptable.',
#  'i also like the fact that they have fresh squeezed orange juice.',
#  'the octopus sashimi is my favorite!',
#  'this is a fantastic location, especially because of teresa m!',
#  'i was pleased with their service.',
#  'you get so much for the price and the food is fresh and delicious.']

# %%
sentences = []
for s in sentences_pos:
    sentences.append((s, "positive"))
for s in sentences_ne:
    sentences.append((s, "negative"))

# %%
sentences[0]
# Out:
# ("Ever since joes has changed hands it's gotten better and better.",
#  'positive')

# %%
labels = [label for _, label in sentences]
labels
# Out:
# ['positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  ...]

# %%
sentences = [sentence for sentence, _ in sentences]

# %%
sentences
# Out:
# ["Ever since joes has changed hands it's gotten better and better.",
#  'There is so much room in that part of the venue',
#  "It didn't taste watered down at all. ",
#  "She said she'd be back, and didn't disappear at all. ",
#  'This pharmacy is really considerate.',
#  'just left and put it on the bill.',
#  "it isn't perfect, but it is very good.",
#  'definitely not disappointed that i could use my birthday gift!',
#  "great new owner, i heard - but i don't know the details.",
#  "but it probably doesn't suck too!",
#  'the service was quick and responsive',
#  'the price included miso soup and a great salad',
#  'they asked how everything was',
#  'they said we could sit at the table with no hesitation',
#  'the store front was well attended',
#  'these chips are okay but their salsa is really tasty',
#  'the wine was above average and the food was even better',
#  'staffed primarily by teenagers who understand customer service',
#  'the burgers were cooked perfectly and the meat was juicy',
#  'blue cheese dressing was above average',
#  'the pad thai tasted like the best I have had in a while',
#  'she said she was pleased to help',
#  'managment is top notch, the place looks great',
#  'there was a wide variety of meats and breads',
#  'when I complained they addressed the issue',
#  'She seemed happy to be there',
#  'besides the shape, they were moist and yummy',
#  'the associates program may still be an option',
#  'The decor was nice',
#  "we got coffee and we'll think about going back",
#  'The sales people are great.',
#  'Salsa is hot and good. ',
#  'I might consider asking for the card to be refunded. ',
#  "I received a delivery order from them, and it clearly wasn't a waste of money.",
#  'I would let her do further things for me in the future.',
#  'they were very upfront and let me know everything',
#  'the beans were in the burro and the rice was plentiful',
#  'they were very fair and respected me since im so young',
#  'we have sent so many people there and they all praised the restaurant',
#  'such nice customer service, they listen to anyones concerns and assist them with it',
#  "they don't need to work on their customer service and general attitude.",
#  ' i continued eating and later we went back to the beer.',
#  "my ``hot'' sub was hot and the meat was tender.",
#  'when i first came to phx... yes this sounded american to me.',
#  "you won't find a better selection in arizona.",
#  'I asked for thai hot and received plenty of spice.',
#  'I felt fine the night after.',
#  'I left full and satisfied, will visit again.',
#  'I just left this car wash and was very satisfied!',
#  'Had one great meal and said,"we\'ll try again."',
#  "The food is good, and the service is one of the best I've ever encountered. ",
#  "I'm looking for wedding dresses, and this one was my first stop!",
#  'He told me kindly how to fix it. ',
#  'Go to this place they are excellent!',
#  'She was happy that we were asking for the prices.',
#  'one of several saving graces was the black beans ',
#  'gained a long time customer!',
#  'other than that, food here is pretty great.',
#  'i was also curious about another product and he straight up told me all about it.',
#  "so far i'm really impressed.",
#  'My groupon was available for many windows.',
#  'Safeway has earned my business.',
#  'The food was great, I would go there again.',
#  'I will be using the place again.',
#  'This is a great venue.',
#  "You'll be wanting more after the first bite!",
#  'Go here the food is very good!',
#  'Everything is always in stock here. ',
#  'The owner was such a friendly person.',
#  'This place is a great place to live!',
#  'after the hobby shop i stopped in for a soda and enjoyed it',
#  'my dish had the perfect amount of salt and the garlic crab was great',
#  'the blended up chicken was made just the way i wanted it',
#  'service was quick and swift',
#  'one of the best happy hours anywhere',
#  'the rooms were spacious and food was very well cooked',
#  'the excecutive chef was nice and said good morning to us very often',
#  'such a great indian restaurant',
#  'the brown sauce was very authentic',
#  'i will come here very often as they give us ample time to play',
#  'was very happy with what arrived.',
#  'his offer of a"free dessert" was even more appreciated.',
#  'i was so full i could not way for the rest of the day.',
#  'the salads are great, really something special.',
#  'overall it was an exceptional evening.',
#  'she would have apologised but she was in a hurry',
#  'there was more people than the usual so it was a little backed up',
#  'he did a great job and continues to',
#  'it was sitting out for a while on the counter because someone forgot it there',
#  'it seems it was warmed up a tad too bit',
#  "i know i shouldn't have sent this back and walked out.",
#  'they will tell you though.',
#  ' i love the food... and service here is awesome.',
#  ' gammage itself however is so amazing.',
#  'needless to say i will be back for mexican food.',
#  "my order was great and i'll do it again",
#  'my opinion is great for this place',
#  'she apologized immensily',
#  'price were better then retail',
#  'the place was exactly as expected',
#  'It smelled and tasted wonderful.',
#  'It was indeed.',
#  'The beer sauce was terrific.',
#  'The building looks modern.',
#  'We loved the cream pancakes too.',
#  "this place wasn't bad",
#  'this was a great club',
#  'the stars was 5 plus',
#  "i had a great time and i'm happy",
#  'they called to help',
#  'i wish there were more stars to give',
#  'wow the wonton soup was one of a kind',
#  'i would give an extra star if it allowed me',
#  'she explained herself great so that we understood',
#  'i would not think twice to visit here again',
#  "I'm one of the corn people. ",
#  "It's not always busy, and the restaurant is very clean.",
#  'I could eat this pizza even if I was insanely drunk. ',
#  'as an Arizona native, I love going to the improv.',
#  'We were seated quick as soon as we got there, then we glady chose colors.',
#  'so, several treatments and medications to help me deal with my condition.',
#  'at this location the service was awesome.',
#  'so who do i call to give my money to.',
#  'cooked so well that it would never be confused for canned tuna fish.',
#  "i'm not stuck in a lease and if I was i wouldn't move.",
#  'service was fast and responsive',
#  'our waitress showed up quickly',
#  'the food was great and perfectly priced',
#  'delivery times were fast',
#  'went back and they helped me quickly on the filling',
#  'i expected so much less from this ny staple.',
#  'i had to leave a message, and they quickly called me back.',
#  'the food is way better than you find in the freezer section at walmart.',
#  "they didn't need to try real hard to get me to come back but i did.",
#  'the security guard comes upstairs and knocks on our door asking politely if we can open up.',
#  'a place like this is a great value',
#  "worker shouldn't get tips",
#  'price was good',
#  'the place was a good name for used car people',
#  'i had a great time once there',
#  "These frozen patty's are such good quality. ",
#  'I will be coming back here very great experience. ',
#  'This is the best walmart out of all of them. ',
#  'The new management team is great!',
#  "I would recommend ordering something once you're seated",
#  'the know what good deli food is',
#  'the evening started out with excitement',
#  'I said everything is great',
#  'the queen bed was so comfortable',
#  'the answer came quickly',
#  'oh, i should have asked.',
#  'my toddler found a mouse toy under one of the seats.',
#  'this place is just great.',
#  'i have to say i was truly impressed.',
#  'this is the reason i will always go back.',
#  'There are plenty of sausage and bacon options.',
#  'The manager was friendly and accomodating.',
#  'The office apologized about the experience.',
#  'It was way better.',
#  'There were plenty of smiles and quality customer service.',
#  "When she didn't answer him quickly enough, he patiently waited on her.",
#  'The fried rice was great and there was a lot of it.',
#  " If your patio is south facing, you're in luck.",
#  'Plus the dude knew how to work the computer.',
#  'Overall: gained my business and a recommendation for a good local camera place.',
#  'it was so funny, i asked her if she was joking?',
#  'the food was great, not too greasy and cooked well.',
#  'food was hot (and fresh), i had the ribs.',
#  'was busy, no biggie.',
#  'the bathroom area is something special.',
#  "Thank goodness the room he found didn't reek of smoke!",
#  'The food there is great compared to buffet standards. ',
#  'I chose not to bring my business elsewhere. ',
#  'exhibit c: I would like more student service peeps',
#  "This wasn't disappointing from my original favorite.",
#  "didn't have to wait long",
#  'the tzatziki sauce had the right amount of dill',
#  'texture of the meat was perfect',
#  'i will go back to the salon',
#  'they received lots of stars',
#  'i would visit there again if the price was right',
#  'they are usually very warm',
#  'the food is great but the employees werent moving fast enough ',
#  'the food was different',
#  'the tech did not realy mention this',
#  "i'm from the bay area and this was a pleasant surprise and well priced.",
#  'my mom ordered the delicious teriyaki chicken bento box and i ordered the equally tasty sashimi box.',
#  'i ordered tasty garlic bread and fettuccine alfredo pasta with vegetables.',
#  "it didn't take that long to cook our sliders!",
#  'the sandwich was great.',
#  'the man stopped her.',
#  "um...we just told him, sure we'd go ahead and finance!",
#  "tasted really fresh, i couldn't believe it.",
#  'it is also very affordable, just to my taste.',
#  'food was very good, we ordered off the mexican menu.',
#  'the brownie dessert was to die for',
#  'the restaurant had a lot of style',
#  'the addressed all the broken items',
#  'the restaurant has been great throughout the years',
#  'my plate was full of food',
#  'When I arrived, someone was at the desk.',
#  'We gave it another 5-10 minutes, then decided not to leave.',
#  'Even the ice cream was very, very unique and good.',
#  "Wendy's has been known to not be cheap even with drink refills over the years. ",
#  'As soon as they delivered I was in awe.',
#  'The service is excellent, and the restaurant is way above average. ',
#  "This is so good, that I guarantee I couldn't have cooked it better!",
#  'This was great, is all I can say.',
#  'I bet they have a fountain machine on site!',
#  'His egg sandwiches smell good and I like the texture.',
#  'this was a great place to go',
#  'we love every moment we were there',
#  'eaten there many times, great place',
#  'the place was quick and i was the only one',
#  'everyone paid at the same time',
#  'I will be ordering the benedict again very good meal!',
#  'Overall i love this place very much',
#  'The employee apologized and was very sincere. ',
#  'They were so quick and they get you in very quickly.',
#  'I would rate this 5 stars!',
#  'in the long run, they were so helpful',
#  'story began at noon today, right on time',
#  'i should shop here more often',
#  'one of the gems in the valley ',
#  'their inventory was top notch, great selections',
#  'chicken fried chicken was tender and the green chili macaroni and cheese was terrific.',
#  'so he can charge a reasonable price for them.',
#  'were we impressing her or something?',
#  'this place has delighted me once again.',
#  'sign a lease with these people immediately.',
#  'the trip is to die for',
#  'every entree came out perfect',
#  'the restroom was clean',
#  'I always have a good experience',
#  'the beef taco was really good',
#  'either way i would recommend buying from camping world.',
#  'excited, I went to sit down and wait for my order.',
#  'its also a very clean park.',
#  'i called and got an immediate response.',
#  'they only charged me for work done, and parts installed.',
#  "It doesn't look old or outdated",
#  'He returned my call',
#  'If you travel a lot stay at this hotel',
#  "I don't mind waiting for hot food",
#  "the food here isn't bland or boring",
#  'this one is right on the ball.',
#  'for the record i am a terrific cook, i use all kinds of seasoning!',
#  'the tow package is just great, too.',
#  'never crowded, plenty of opportuinity to have a good time.',
#  "i think it's wonderful when employees act that way.",
#  "i won't keep looking for a different salon now.",
#  'you can not pay me to not ever shop here!',
#  'french toast plate was good, mom said, eggs were hot.',
#  'now the food : not bad, above average.',
#  "this is easily the best greek food i've had in my life.",
#  'I want to give this a 5 out of 5 star rating.',
#  'When it came we were so happy. ',
#  'The equipment is very new and looks good.',
#  'Im willing to take the chance!',
#  'This place smelt new and fresh.',
#  'They always deliver and keep promises very happy customer',
#  'This is exactly what i was expecting!',
#  'Everything was so special about this place ',
#  'Razz accomplished everything ',
#  'The management cares so much for the golf experience.',
#  '20-30% capacity at most, I enjoyed being the only one in the pool.',
#  'The chow mein was very consistent and had a nice texture.',
#  'Found the place even though it is easy due to good signage.',
#  'Am sure, and I care!',
#  'Two hours of my life I was happy to give up.',
#  'Very great experience with the red purse and wonderful black shoes. ',
#  'Very happy right now and will re visit in the future to this place.',
#  'Service was great, Very short wait time, highly recommend.',
#  'Very great time here for the 2nd time.',
#  'The bread was amazing, and the dip was incredible',
#  'he readily offered another time for me to come in.',
#  "what's that interesting thing you are doing?",
#  'the lady at the front desk was very friendly.',
#  "i was impressed, and I'd recommend this place.",
#  'the dipping sauce was pleasantly sweet as well.',
#  'The cheese crisp was perfect and crispy. ',
#  'I was able to use my certificate because it was good still.',
#  'truth truth be told!',
#  'Very great parking signs very easy parking experience. ',
#  'This was a very great place to dine in at.',
#  'pretty great food and service.',
#  'this is an old vintage hotel.',
#  "the pizza is great without toppings and it's packed in flavor.",
#  'the mechanics are very professional as usual.',
#  'this place is beyond a great place.',
#  'This place is very nice with great service.',
#  'This turned out exactly how i thought it would. ',
#  'Went in for an adjustment and everything worked out.',
#  'The service was amazing. ',
#  'I would recommend everyone to try this starbucks',
#  "the only thing i wasn't offered was a free dessert.",
#  'management really seem to care.',
#  ' i had a great experience, and i happily would come back.',
#  ' it is really brown rice.',
#  'even got a response.',
#  'i contacted the store manager and he gave us a great compensation',
#  'the staff treated her nicely when she came in for her alterations',
#  'the ceasar salad and blackended chicken were to die for',
#  'the establishment had the perfect temparature',
#  'she offered me a soda while i waited which was very nice',
#  'I emailed to let them know they really do care.',
#  'I almost forgot how great their offerings really are!',
#  "I bet it's going to get finished.",
#  'We will definitely be coming back!',
#  'He could really read her pressure, though.',
#  'Absolutely fabulous, do order from this place.',
#  'ate kicked ass, marquee, pretty good too.',
#  'Even the water tasted great.',
#  'and the food is simply as good as other locations.',
#  "Sounds great doesn't it?",
#  'the ac was not working properly but its usually a good temp in there',
#  'it was large and good enough for 2 people',
#  'it was a little overcooked',
#  'he is usually on the calmer side but he must have been having a bad day',
#  'the prices are on par with frys',
#  "too bad it wasn't at the expense of the other customers.",
#  "we'll see if that doesn't happen, but i'm not holding my breath that it won't.",
#  'and management does something about it.',
#  "no wonder these restaurants aren't closing up all around the valley.",
#  'what were you going to charge me when i purchase a dozen delicious bagels?',
#  "i'm still craving my awesome drunken noodles!",
#  'these days the quality is pretty up to par.',
#  'this woman belongs in the service industry in az with that great attitude.',
#  'service was above average as well as the food and drink.',
#  "my husband didn't have to walk up to the bar to place our wine order.",
#  'The pizza was warm, not greasy, and generally tasted great. ',
#  "I don't think they were having a bad night. ",
#  'This place is clean, not run down, and the service was great.',
#  'Everything was hot including the coffee. ',
#  'I would never put it in the trash.',
#  'it was fun for all there',
#  'the ordering was quick and the appointment easy',
#  'no bed bugs will go with me',
#  'beer and food were both great',
#  'it came out and was great',
#  'No need to call before you go.',
#  'The food was good and the service was good.',
#  'Crab cakes were salty and delicious.',
#  'The customer service made it for me.',
#  'I walked over and called the manager to compliment.',
#  "I wasn't disappointed with this place at all. ",
#  "Don't worry, you weren't my problem. ",
#  'The tour guides are experts.',
#  "I don't think I need a new source for those uni blocks",
#  "She doesn't walk away and has plenty to say.",
#  'The short rib hash was perfectly cooked and juicy.',
#  'The staff was consistently present.',
#  'It tasted amazing and had a great consistency.',
#  'She is good at any time.',
#  'He took care of the bill himself.',
#  'No need to worry about patience.',
#  'What a wonderful use of my time.',
#  'Two for my dogs equally.',
#  'I looked really close.',
#  'The server was totally buying.',
#  'best customer service i have ever had.',
#  'great what has happened to this sandwich shop.',
#  ' and for this reason, i will return.',
#  'this branch is getting better and better.',
#  'they happened to tell us eating in the bar was an option.',
#  'they can thank you for a good rating',
#  'i ate all of it',
#  'this was the first time i ever cried of happiness from a haircut',
#  'there was a friendly server with a great personality',
#  "if I wasn't with my coworker I would've danced for joy",
#  'Ra was a chain, wow im impressed',
#  'they got it right, didnt take them long',
#  'went to sunday brunch and had a great time with my daughter for her graduation',
#  'the got the spice right this time after a few tries',
#  'game room was pretty decent, well worth the price',
#  'I told him I would leave excellent feedback online.',
#  'The manager told me my order was coming up any minute!',
#  "I bet it's a good thing, and not a bad thing. ",
#  'Maria the manager is an outstanding person. ',
#  "It was so good that I didn't want out of there.",
#  'we told them not to forget it, we wanted to wait.',
#  'first, the bartender was awesome.',
#  "absolutely awesome, can't stay away from this place.",
#  "i guess great restaurants don't have bad days.",
#  'oh well, they care... right?',
#  'we will definitely be spending more of our money here',
#  'i will be back to get another lv bag',
#  'great pieces all even, glad i paid the price i paid',
#  'we left with a lot of things that day',
#  'such great service, cannot praise it enough',
#  "It's thin and tastes amazing.",
#  'I had delicious crackers for my soup.',
#  'I love huge chain restaurants.',
#  'The rice was warm and the taste was great.',
#  'You can judge people based on their character.',
#  'decent pizza they had here',
#  'the pasta came out great and tasty',
#  'the food was great and very courteous',
#  'would recommend anyone to live here',
#  'got in quickly',
#  'great food and excellent staff and very very nice workers.',
#  'It was my favorite weekend visiting my folks.',
#  'next dish was moo goo gai pan to which the awesome sauce is the secret.',
#  'do not go here if you are interested in eating bad food.',
#  'prime rib was not fatty and was cooked per request.',
#  'I gained more respect for this company.',
#  'We will stay with this walgreens location.',
#  "I'm going back to the bar and making it to the restaurant.",
#  'The place was incredibly busy.',
#  "It's like an actual irish pub.",
#  'The birthday surprise was a success as well as her special day.',
#  'Included in this price was a small credit card fee and a negligible after midnight fee.',
#  'The other item I was able to eat was the wonderful broccoli beef! ',
#  "Other than that, I really don't know what was bad about it.",
#  'The food is very authentic.',
#  'actually, go on in.',
#  'fortunately, it is the best.',
#  'the place has obviously improved over the years.',
#  'much more these days.',
#  'looked forward to experiencing the restaurants closer to asu.',
#  'this location is not that great but it was great before',
#  'the door was jammed',
#  'services were fast and we tried to help everyone equally fast',
#  'there might be something wrong with the hallway ac but it has since been fixed',
#  'the order was placed but the waiter did not get everything right so he asked them to repeat the order',
#  'i may just post pictures to prove their high quality work.',
#  'it is way under-priced ( compare to what they serve!',
#  'this is a great college.',
#  'my jack and coke was seriously popping.',
#  'happily, i will probably be able to eat at this place again.',
#  "The falafel's were so amazing, and had such a rich flavor.",
#  'The place was empty with minimal customers!',
#  'This food was great for diners. ',
#  'The food was perfectly cooked, and lots of great seasonings. ',
#  'My noodles were so good, and the bowls held everything i place.',
#  'go here no matter what.',
#  'I thought the prices were fair.',
#  'She was pretty good with the estimated time for a table.',
#  'The prices were great.',
#  'They had plenty of cheese packets and red pepper.',
#  'went into this awesome location to drop it off.',
#  'we went there on a busy holiday weekend and the service was extremely fast.',
#  "if i was the manager, i'd promote that kid on the spot.",
#  'too sweet too because they brew an outstanding beer.',
#  'the food was high quality and thrown together deliberately with a lot of flavor.',
#  'The beer tasted fantastic.',
#  'The woman in the deli was great.',
#  'I will always go back to kfc - they earned my patronage.',
#  'There are no better places for breakfast.',
#  'The older waitress was a real sweetheart.',
#  "It's a very pleasant surprise.",
#  "It doesn't ever need replacing.",
#  'Amazing place, great food.',
#  'I will be returning to this place frequently.',
#  'The fees are comparable to other places.',
#  'anything they say, they give in writing.',
#  'this is a close call from real new mexican cuisine.',
#  "but fortunately the rude woman wasn't the one checking us out.",
#  'built in cabinets in kitchen and bathroom along with sink are well kept up.',
#  'good service in these areas and really made our visit.',
#  "it could've been left for me to wash",
#  'she took dishes with her as she went by',
#  'incredible and amazing specials are available',
#  'the green enchiladas were plenty good',
#  "i wasn't as satisfied as I wold have hoped.",
#  'I tried to much success',
#  'university is not so bad like living on apache',
#  'good job on nails and toes',
#  'I opted to purchase the pictures based on quality.',
#  'bread was offered at no charge',
#  'Simply, this is a superior place to go for sushi.',
#  'Took my suit to get fitted and they put a new button on it for me.',
#  'Trustworthy pizza delivery!',
#  'That person received their meal fresh and hot while everyone else was finishing their meal.',
#  "The place was quaint, I'm sure she could have figured it out.",
#  'They pay very much attention to customers!',
#  'Everything was good, and the desert was very tasty.',
#  'Very nice massage made my maicure and pedicure great',
#  'I called at 630 and was helped right away!',
#  'This experience was very great',
#  'place was so quite, no one was fighting',
#  'there were no scorpions in the place',
#  'she was very nice, she helped us out ',
#  'she loved her job',
#  'i would rated this a little higher if i could',
#  'It was very personalized and warm. ',
#  'Everyone waited to eat until everyone seated had theirs. ',
#  'I love the size of this dance floor!',
#  "It's good this location has double the staff, since it's so busy. ",
#  'Starbucks services are good at every location!',
#  'they had awesome stringed cheese',
#  'it was luckily not the ones at asu but the ones in junior high',
#  'three woman met for a nice lunch last friday at elements at the sanctuary',
#  'ra sushi, you are so amazing to me',
#  'half of my head was processed well',
#  'a young woman did my pedicure.',
#  "like it hasn't been in a fridge for a week.",
#  '``yes, we are going to have a tournament tomorrow.',
#  'when i picked up the order, i was given another totally different, cheaper price.',
#  'they stock some of the most common parts.',
#  "it's small yet they make you feel right at home.",
#  'i will be going back and enjoying this great place!',
#  'the drinks were affordable and a good pour.',
#  'my husband got a ruben sandwich, he loved it.',
#  'i signed up for their email and got a coupon.',
#  "i'd definitely recommend giving them a try.",
#  'i highly recommend e & m painting.',
#  'otherwise a great experience and we will go again.',
#  'good drinks, and good company.',
#  'oh i got my band geek back on now!',
#  'i was nervous and she made me feel so comfortable and welcome.',
#  'great food recommendations steak and tuna were both great.',
#  'everything is fresh and so delicious!',
#  'the biscuits and gravy were good.',
#  'i actually can wait to come back next year!',
#  'they were so helpful, kind, and reasonably priced.',
#  'god i love pei wei.',
#  'friendly folks, delicious authentic bagels, tasty cream cheese.',
#  "you'll see why once you get there.",
#  'everyone that i spoke with was very helpful and kind.',
#  'the variety of sushi rolls makes for a good eating.',
#  'and every experience has been a positive one.',
#  'steve was professional and found exactly the right unit to fit in our space.',
#  'this golf club is one of the best in my opinion.',
#  'excellent knowledgeable dentist and staff!',
#  'portions are very generous and food is fantastically flavorful.',
#  'always fresh, fat, and delicious.',
#  'these two women are professionals.',
#  'the most important thing, of course, is the food.',
#  'we were both so impressed.',
#  'very good brunch, was impressed with selection and quality.',
#  'the menu is very simple, healthy, and tasty.',
#  'she was spot on as they were delicious.',
#  'i love this place, the service is always great!',
#  'perfect spot to shop for gift!',
#  'a great stop if you want nice things at a steal.',
#  'the atmosphere was fun and the staff treats you well.',
#  'their front line is so much cheaper than petsmart!',
#  'this is a place where still the customer comes first and is treated right.',
#  'i also love their convenient location right off of scottsdale road.',
#  'their pizza is the best i have ever had as well as their ranch!',
#  "i'm so happy and will definitely go back for future services.",
#  'seems pretty high compared to every other thai place.',
#  'she did the most amazing job.',
#  'really enjoyed the beautiful range.',
#  'they have a fantastic selection and a very knowledgeable staff.',
#  'definitely a place to keep in mind.',
#  'great place to hang out, grab a meal and a few brews!',
#  'the lunch and dinner items are very good as well.',
#  'charlie was clean neat and professional.',
#  'the calzones are awesome and the lunch special they have is perfect.',
#  'i will definitely return often!',
#  'they have delicious soups everyday.',
#  'nice people, prompt service and clearly expert.',
#  'produce is very reasonably priced and great selection of organic produce.',
#  'the food here is delicious.',
#  'first time i came in, i knew i just wanted something new.',
#  'certainly a good choice if going to a performing arts center event.',
#  'this place has been making great sushi and sashimi for years.',
#  'even in summer, they have decent patronage.',
#  'you will be helped by all of their friendly advise, and travel knowledge!',
#  'i spent time with my best buds and enjoyed some excellent wine and food.',
#  'we went with a group of eight and all had a great time.',
#  'the service has always been wonderful.',
#  'thanks for making our special night an event to remember.',
#  'i had a spanish omelet was huge and delicious.',
#  'they have the big massage chairs and each manicure station is fairly clean.',
#  'the wait staff is extremely attractive and friendly!',
#  'also, the food is great!',
#  "the color that she uses on my girlfriend's hair looks great.",
#  'it is consistent and the staff is always friendly.',
#  'friendly and welcoming with a fun atmosphere and terrific food.',
#  'the chicken chimi i had was absolutely fantastic!',
#  'it is also fun to sit at the bar.',
#  'the soup is absolutely to die for.',
#  'the best mexican food in the phoenix area.',
#  'they are professional, thorough and attentive to our needs.',
#  'their lunch special is a great value!',
#  'our experience with this business was positive.',
#  'the staff is awesome and location is right in the heart of old town!',
#  'you have to sit outside to get the best experience from this place.',
#  'the food is delicious and plentiful.',
#  'and the fettuccine alfredo is absolutely scrumptious!',
#  'we dropped our rental truck of at this location two weeks ago.',
#  'this adds the last little touch to what was already an amazing place.',
#  'prices are a tad high but worth it.',
#  'the message therapist is awesome also.',
#  'came here with my family.',
#  'the owner replied, i will go in half with you.',
#  'the escargot was delicious, and seasoned perfectly.',
#  'brittany gave me a very new haircut and transformed me completely.',
#  'this resort has been in scottsdale forever and it truly knows service.',
#  'also the crab wontons rule along with the spicy plum sauce.',
#  'i have gotten so many dresses at a steal of a price!',
#  'all around great place to grab a drink or two.',
#  "the flourless chocolate cake was one of the best desserts i've ever had.",
#  'beautiful scenery and friend staff.',
#  'nice wine list at 2x retail rather than the more typical 3x.',
#  "we loved our day on the river and can't wait to go back!",
#  "if you're young and are into sports this is the place for you.",
#  'i love their star design collection.',
#  'i love their fresh juices as well.',
#  'definitely a must do if you have time in the phoenix area.',
#  'oj and jeremy did a great job!',
#  'tires, alignment, brakes and more.',
#  'it was very good to!',
#  'staff : very cute and friendly.',
#  'love the afternoon - tea at the phoenician.',
#  'their enchilada sauce perfectly complemented this dish.',
#  'beautiful decoration and great service.',
#  'very pleased with service and quality of work.',
#  'one of my favorite places to go for a great steak.',
#  'this place is super yummy!',
#  'they are spacious with modest decor.',
#  'this is my go to neighborhood place.',
#  'the people at sonora were very good to me.',
#  'the patio is a fun place to sit at 7pm.',
#  'it was well worth it.',
#  'oh sushi kee, how i love thee!',
#  'she kept our drinks full and gave us great food recommendations.',
#  'loved the burgers, i had the jalapeo ranch burger it was really tasty.',
#  'great kebab dishes and good service.',
#  'i got a bagel breakfast sandwich and it was delicious!',
#  'the service was amazing and the staff was very friendly.',
#  'pool tables and inexpensive drinks make this a fun night out!',
#  'the eggs are always fluffy, the side of fruit always good.',
#  'pricing is both affordable and reasonable.',
#  'these guys are top notch, honest and very reasonable.',
#  'they made me feel like i was at home and their an extended family!',
#  "sometimes it's a simple cut, other times is more complicated color.",
#  'giving an extra star for customer service.',
#  "it's a big bowl of sweet happiness.",
#  'one of my favorite chinese place to eat!',
#  'always good after the river too.',
#  'food good, a plate went a long way.',
#  'the service was great and would gladly go back.',
#  'i love the pork tacos.',
#  'everyone is friendly and knowledgeable.',
#  'nothing but happy thoughts from anyone i have sent their way!',
#  'enjoyed the dolly a lot.',
#  'jennifer is great and she really makes skin care affordable.',
#  'this is a rare gem and i am excited to have found it.',
#  'this is pretty darn good pizza!',
#  "everything we've ever ordered here has been great tasting.",
#  'it is the most authentic thai in the valley.',
#  'great staff and wonderful food.',
#  'love the mole sauce, chips are nice and thick.',
#  'go here, you will love it.',
#  'i loved the ribs more than the chicken.',
#  'staff and the ride were terrific.',
#  'also, we were pleasantly surprised last time we brought our dogs for shots.',
#  'i reccomend the drunken dragon noodles ( for you spicy lovers! )',
#  'for a local chain this place is great!',
#  'this place reminds me of home!',
#  'one of my regular spots in scottsdale.',
#  'i will definitely go here again!',
#  'stopped in for lunch, nice wine list, good service.',
#  'i love that this is the place in the comic - family circus.',
#  'it is an international delight.',
#  'it was just so cute and quaint!',
#  'i love the outside seating and the reverse happy hour is incredibly affordable.',
#  'the atmosphere is at the sugar bowl is fun.',
#  'with that being said, i enjoyed the food.',
#  'great food, great decor!',
#  'the food is always fresh.',
#  'you can come in, spend any amount of money and enjoy something amazing.',
#  'all of the food that i had was excellent.',
#  'so far, great customer service.',
#  'rick is a seriously cool guy!',
#  'we ate here yesterday for happy hour and it was fantastic.',
#  "that's a rare find in a business.",
#  "it's good solid food.",
#  'nice club good layout the course was in good to above average shape.',
#  "we'll certainly be back!",
#  'the meatloaf ( when they have it ) is amazing.',
#  'food here is also so good!',
#  'thank you amanda, i will be back!',
#  'i love their flavored coffee.',
#  'the staff made us feel very welcome and comfortable.',
#  'the food is good and from what i can tell is rather authentic.',
#  'i would recommend dentistry of old town scottsdale to everyone.',
#  'my father has decided to upgrade my mothers engagement ring this xmas.',
#  'the best deals in the store are on these racks.',
#  'the guys here are sooo incredibly nice and helpful.',
#  'will bring all my vehicles back for sure!',
#  'the salsa was fantastic although next time i will ask for a hotter one.',
#  'great place to have some fresh and delicious donuts.',
#  'came here to get breakfast and that was the best decision yet.',
#  'they have an excellent selection of combos to choose from.',
#  'they were great, not too greasy but fluffy and light.',
#  'great selection of salads and pasta items in the deli.',
#  'overall really good quality food and service.',
#  'everyone was extremely nice and professional.',
#  'i got the tamale sampler.',
#  'also matt was super cool and helpful.',
#  'cleaned my plate, perfect amount of food.',
#  'and again, the food is incredibly delicious!',
#  'but it is definitely worth the wait.',
#  "grimaldi's is the most consistently amazing pizza place in arizona.",
#  'nothing but excellent customer service every time i come here.',
#  'great service by the staff.',
#  'i also get dessert here when i have a sweet tooth.',
#  'i always have a great dish here to eat.',
#  'this is by far my favorite pizza.',
#  'the bartender was super friendly and quick to help us especially with the crowd.',
#  'service was great as they continued to check on our table.',
#  'thank you ladies for being awesome!',
#  'awesome and fast service, these guys really know their stuff.',
#  'a great museum to visit.',
#  'nice for me to go and work and have a great breakfast!',
#  'okay prices and great tastings at least once a month.',
#  'our waitress was the best, very accommodating.',
#  'while the menu is simple, what it does offer is truly first-rate.',
#  'its not cheap but you get good value here.',
#  'nice menu, good prices, great service - for both dinner and breakfast!',
#  'good food, great prices on wings on tuesdays.',
#  'the place was busy but the service was excellent!',
#  'tonight though i ordered to go and the food was just as good.',
#  'this place has some great food.',
#  'the two gentle men up front are always so kind.',
#  'the salsa is great, the fish top notch, the drinks just excellent.',
#  'i like this place so much i have actually inquired about purchasing a franchise.',
#  'and the seafood enchiladas were great!',
#  'the bread is definitely home made and i could probably eat it all day.',
#  'the portions were huge, the food came out hot, fresh and good.',
#  'a bit on the noisy side but the fresh food makes up for it.',
#  'ambiance and setting were superb.',
#  'pizza was cooked to perfection and fast!',
#  'our bartender erik took care of my fiance and i very well.',
#  'everyone who works there is always so happy and friendly.',
#  'i love the cornbread appetizer.',
#  'ordered the huevos rancheros and it was delicious!',
#  'the customer service in this location is great!',
#  'the firecracker shrimp and duck is also always a winner.',
#  'service was wonderful to match!',
#  'the service is friendly and attentive.',
#  'great food and awesome service!',
#  'this place still kicks ass.',
#  'biscuits and gravy are a great breakfast item too.',
#  'always a great experience there with the owner and the rest of the team.',
#  'well worth searching out this gem.',
#  'my husband and i enjoyed our 3rd anniversary here.',
#  'this is a golf course that is tucked away it is in great condition.',
#  'plus my sparkling wine flights were delish!',
#  'pricy but the cheese pies are delicious!',
#  'the bbq salmon was good.',
#  'the best part of my thanksgiving dinner by far was sweet cakes pecan pie.',
#  'even their steamed veggies are amazing.',
#  "this place is a must go if you're a bride to be!",
#  'excellent combination of flavors, very unique.',
#  'mustard beef ribs are a must.',
#  'i had the burger once and it was juicy and very flavorful!',
#  'i rate the experience as followed.',
#  'always order the tzatziki sauce with everything you get!',
#  'my meal was very satisfying and flavorful.',
#  'try anything on the menu and you will be glad you came in!',
#  'bartender made a great dirty martini!',
#  'omg carlsbad tavern is awesome!',
#  "other than that, it's great!",
#  'best breakfast i had on my recent trip to scottsdale.',
#  'extremely attentive and genuinely a good person.',
#  "it's basic, traditional, mexican food that is homemade and tastes great.",
#  'food is very fresh and amazing!',
#  'the environment was cozy, the servers were friendly and on top of things.',
#  'fish tacos were pretty good.',
#  'absolutely hands down the best dentist office in the east valley!',
#  'they are all very friendly.',
#  'he always looks gorgeous and is so happy when i pick him up!',
#  'i love italian and i eat here often.',
#  'quality of food is fantastic.',
#  'the service was excellent and my hostess was very nice and helpful.',
#  'the best bar in town.',
#  'they are always doing a good job.',
#  'russ was a well qualified tech.',
#  'when we get into town, this is the first place we come!',
#  'thank you fiesta, lunch with you is always good.',
#  'they also are the best price in the area.',
#  'green chile chimis are fantastic.',
#  'thanks for the perfect repair.',
#  'casual atmosphere, upscale food.',
#  'had dinner here last night and it was great.',
#  'the marinara sauce is so flavorful.',
#  'they are incredibly nice and accommodating.',
#  'the service was top notch and the food was a bit of heaven.',
#  'it can be pricey, but it is really worth it.',
#  'wonderful staff, wonderful food, excellent prices.',
#  'portions n prices were great!',
#  'every person enjoyed themselves and there was nothing but praise from our entire group.',
#  'outstanding persian food not to mention service.',
#  'thank you for a fabulous evening!',
#  'my daughter received great care.',
#  'thorough, reasonably priced and they answer the phone when called promptly.',
#  'they were very friendly and apologetic.',
#  'the wine list was the best part.',
#  "it's a much better option than the club scene.",
#  'i ordered the carne asada steak and it was cooked perfectly!',
#  'that comes with the smaller location though.',
#  'fun place to go drink beer.',
#  'it is very very family oriented and we loved that too!',
#  'even the sides were great.',
#  'she did an amazing job on my color and my cut!',
#  'the owner is a hoot and the facility is very accommodating.',
#  "totally will come back next time i'm in town.",
#  'he was both professional and courteous.',
#  'this course is one of the finest in the area.',
#  "if you're into that sort of thing stop by and check it out!",
#  'i enjoy coming here for lunch to get the slices.',
#  'it is a half a day trip from phoenix area.',
#  'love the vibe of this place!',
#  'the staff are all super friendly and on top of there jobs.',
#  'corn bread was also good!',
#  'food super and well priced.',
#  'they loved the rock climb.',
#  'super tasty and a much better deal than the chain sub joints.',
#  'by far the best experience i have ever had in a auto shop.',
#  'so happy with my decision to go here.',
#  'it was pretty inexpensive and they played good music videos.',
#  'very throwback atmosphere; vintage ice cream parlor.',
#  'sit at the bar and eat the small plates.',
#  'the grounds are always very clean.',
#  'i just returned from a delightful stay at the camelback.',
#  'a steak, shrimp and an enchilada.',
#  'they go above and beyond!',
#  "i've been here several times and every time has been great.",
#  'the good news that my vision had improved made the visit even better.',
#  'it is such a cool little place to relax and get swanky.',
#  'we recommend imports & american auto service to everyone we know.',
#  'the girls are very attractive and really friendly, not pushy at all.',
#  'its quiet and nice people are here.',
#  'took home the most delicious white pizza since living here in az.',
#  'after eating several other gyro place kings still has the best sauce.',
#  'service was great and food was even better.',
#  'suzanne and her staff were excellent!',
#  'all in all pretty good!',
#  'fast, friendly and honest service.',
#  'great food, great service, their catering can not be beat.',
#  'i had the best pork belly here ever!',
#  'you can tell how fresh the ingredients are.',
#  "i'll definitely go back here again.",
#  'coupon or not, this place is extra nice and a very good value.',
#  'this is the best seafood joint in town.',
#  'keep up the amazing service!',
#  'every time i crave mexican food, i go here!',
#  'my dr pepper ribs were excellent and very tender.',
#  'everyone is always super friendly and helpful.',
#  "it's hot, cooked perfectly, and delicious!",
#  'travel all around the world and know indian food well.',
#  'very nice location for weekend volleyball tournaments!',
#  ', to name a few shows we have seen here.',
#  'enjoy taking my family here always the freshest sea food.',
#  'friendly owners and staff and delicious food!',
#  'they will even deliver to the school!',
#  'ron is still the greatest.',
#  'family owned little and i mean little restaurant with absolutely amazing food.',
#  'decent selection of meats and cheeses.',
#  'had the normal gyro sandwich with their sauce... very good.',
#  "i just had probably one of the best restaurant experiences i've ever had.",
#  'best green corn tamales around.',
#  'everything they serve there is wonderful.',
#  'fun to watch the kitchen in rush hour.',
#  'place was clean and well kept, drinks were reasonably priced.',
#  'the employees always remember me and my dog, which is very nice.',
#  'we love to come as a family.',
#  'they also found my apartment which is pretty hard to find.',
#  'very helpful, hospitable, knowledgeable, and informative.',
#  "it's located in a great part of scottsdale and was really accommodating.",
#  "but it's worth seeking out.",
#  'super friendly staff, quick service and amazing and simple food done right!',
#  'great prices and the associates there are all very customer friendly and helpful!',
#  'and i had my sugar bowl favorite, the top hat sundae!',
#  'great prices, great selection.',
#  'very good food and service!',
#  'this is the best yarn store in the metro area.',
#  'great lunch specials and awesome staff.',
#  'and have enjoyed every last bite.',
#  'food is always amazing no matter what i order.',
#  'they were extremely friendly and reasonably priced.',
#  'good selection of parts and accessories and reasonable prices.',
#  'the food is great here and very authentic.',
#  'great food, low prices, and an authentic mexican cantina vibe.',
#  'this place offers solid, delicious take out.',
#  "it's a whole new experience and new flavors each time you go.",
#  'myself and family / friends have been going to them for years!',
#  "they've added some new items on the menu since my last visit.",
#  'they bring it out front for you and are very helpful.',
#  'great place to go for games with multiple tvs and a lively crowd.',
#  'all of my clothes are returned in sparkling condition!',
#  "one of best veal dishes i've ever had and reasonable prices.",
#  'the food was good, steak bites and hummus plate a must.',
#  "as far as pizza goes this ranks with the best i've ever eaten.",
#  'really good service and food.',
#  'their sandwiches were really tasty.',
#  'always a fun and friendly atmosphere.',
#  "i'm a regular drive-through customer at this location.",
#  "it was so delicious; i've never had anything like it!",
#  'definitely something i will have again!',
#  'the california burrito was also a great burrito.',
#  'the woman who helped me today was very friendly and knowledgeable.',
#  'the service was great, food delicious, and the value impeccable.',
#  'loved the menu and the drinks.',
#  'pei wei has fair prices, fast service, and wonderful outdoor seating.',
#  'it was a great experience!',
#  'his humor makes a routine visit entertaining.',
#  'love this place and will keep coming back.',
#  'we were sat right away and every staff member was extremely friendly and happy.',
#  'will definitely go back and recommend to friends.',
#  'their small calzone is really gigantic!',
#  'the food is also very good.',
#  'the margaritas were also tasted and the churros with ice cream was also outstanding.',
#  'i highly recommend the ahi tuna.',
#  'she was so patient, kind and understanding.',
#  'heck, even the pizza is decent.',
#  'cooked to perfection and very flavorful.',
#  'the crew was very friendly and accommodating.',
#  'the sushi here is great and i love the cucumber salad.',
#  'if you are looking to walk out transformed this is your place!',
#  'she chose a great color that looks incredible with my skin, too.',
#  'a great place to watch sports!',
#  'this cute little pizza, salad and pasta place in east chandler is great.',
#  'the art in the alley behind it is cool too!',
#  'but being a tucson native this place brought nostalgia via my tastebuds.',
#  'best chicken parmesan i have ever had.',
#  'customer service was great there.',
#  'fun place to catch a game on tv and catch up w/ people.',
#  'most delicious authentic chinese food!',
#  'the chips and guacamole were excellent too!',
#  'this place is wonderful when you can actually sit outside.',
#  'a great little spot to throw back a few beers after a rough day.',
#  'i definitely recommend this place to others!',
#  'well the food was great and the price of it was even better.',
#  "i took the waiter's recommendation of the veal carolina and it was super!",
#  'super good deals and very friendly staff.',
#  'tried their lasagna and its the best ive ever had.',
#  'this place is edgy and fun.',
#  'fantastic place to see a show as every seat is a great seat!',
#  'she was absolutely fantastic and i love what she did!',
#  'the happy hour crowd here can be fun on occasion.',
#  'very busy but very good service.',
#  'best take out or eat in sushi!',
#  'i have had a great experience every time from start to finish.',
#  'he is very thorough and genuinely cares for his customers.',
#  'plus he has amazing prices, how could you not go?',
#  'the staff are very friendly and on the ball.',
#  'all had that satisfying grease flavor that washed down well with beers.',
#  'i was a walk in and got helped right away!',
#  'if you sit in the bar they have the best bartender in town.',
#  'i highly recommend this shop.',
#  'their staff is knowledgeable and informative.',
#  'it is a cool place, with lots to see and try.',
#  'they are super friendly, very helpful, and amazingly quick!',
#  'i got my car detailed here and it looked amazing!',
#  'dr. hall is so kind and gentle.',
#  'i had to box it up even, such a huge portion.',
#  'the food all looked great.',
#  'the menudo here is perfect.',
#  'the crispy mango fish was very tasty.',
#  'now the food, drinks, and desserts are amazing.',
#  'the carne asada burrito is awesome!',
#  'this is the perfect date night.',
#  'nice selection of games to play.',
#  'the grilled artichokes are wonderful!',
#  'the adovada is hot but wonderful and the chocolate bread pudding is amazing.',
#  'fun and inexpensive way to enjoy and relax your day.',
#  'i loved it and will definitely be back!',
#  'got screwed at bar that we made reservations at next door.',
#  'very friendly staff and manager.',
#  'love my cut and color and sage is amazing!',
#  'wide spectrum of ages and races.',
#  'had a blast and the food at their restaurant was excellent!',
#  'at no cost - great service!',
#  'their steak & salsa burrito was very very good and really big too.',
#  'blue corn tacos with chicken were excellent.',
#  'plenty to eat and amazing flavor.',
#  'i definitely will return to the roaring fork!',
#  'it will stay with you all day.',
#  'the hummus is ridiculously creamy and delicious.',
#  'good place for a romantic dinner!',
#  'the owner knows us and treats us very well!',
#  'i can honestly say i am so glad we will be moving to az.',
#  'the green chile mac and cheese was incredible!',
#  'i highly recommend impact auto body.',
#  'great quality, great service.',
#  'and i get the gyro sandwich every time and its the best.',
#  'i highly recommend this bakery!',
#  'love their food and their passion.',
#  'i highly recommend this salon and the wonderfully talented stylist, angel.',
#  'they have a lot of choices for sushi lovers!',
#  'reasonable price, bottom line guaranteed.',
#  'homemade tortillas are so good!',
#  'the prices were the best and worth it.',
#  'amazing food, great service.',
#  'this was the best i have ever had!',
#  'this is one place in scottsdale casual dress is acceptable.',
#  'i also like the fact that they have fresh squeezed orange juice.',
#  'the octopus sashimi is my favorite!',
#  'this is a fantastic location, especially because of teresa m!',
#  'i was pleased with their service.',
#  'you get so much for the price and the food is fresh and delicious.',
#  "ever since joes has changed hands it's just gotten worse and worse.",
#  'there is definitely not enough room in that part of the venue.',
#  ...]

# %%
prompt = (
    "Classify the sentiment of the sentence.\n"
    "Respond with ONLY ONE WORD: positive or negative.\n\n"
    "Sentence: "
)

# %%
tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = tokenizer.eos_token_id

# %%
y_pred2 = []

for text in sentences:
    tokens = tokenizer(text, return_tensors="pt").to("cuda:0")

    output = model.generate(
        **tokens,
        max_new_tokens=3,
        do_sample=False
    )

    input_len = tokens["input_ids"].shape[1]
    gen_tokens = output[0][input_len:]

    decoded = tokenizer.decode(gen_tokens, skip_special_tokens=True).lower()

    if "positive" in decoded:
        y_pred.append("positive")
    else:
        y_pred.append("negative")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ...
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.

# %%
print("Accuracy :", accuracy_score(labels, y_pred2))
print("Precision:", precision_score(labels, y_pred2, pos_label="positive"))
print("Recall   :", recall_score(labels, y_pred2, pos_label="positive"))
print("F1-score :", f1_score(labels, y_pred2, pos_label="positive"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3847651081.py in <cell line: 0>()
# ----> 1 print("Accuracy :", accuracy_score(y_true, y_pred2))
#       2 print("Precision:", precision_score(labels, y_pred2, pos_label="positive"))
#       3 print("Recall   :", recall_score(labels, y_pred2, pos_label="positive"))
#       4 print("F1-score :", f1_score(labels, y_pred2, pos_label="positive"))
#
# NameError: name 'y_true' is not defined

# %%
y_pred = []

for i, text in enumerate(inputs):
    tokens = tokenizer(text, return_tensors="pt").to("cuda:0")

    output = model.generate(
        **tokens,
        max_new_tokens=1, # Set to 1 to force single word output
        do_sample=False
    )

    input_len = tokens["input_ids"].shape[1]
    gen_tokens = output[0][input_len:]

    decoded = tokenizer.decode(gen_tokens, skip_special_tokens=True).lower().strip() # Strict stripping

    # Print decoded output for inspection
    if i < 5: # Print for first 5 to avoid overwhelming output
        print(f"Original Sentence: {sentences[i]}\nModel Output: '{decoded}'\n") # Added quotes to clearly see output

    if decoded == "positive":
        y_pred.append("positive")
    else: # If not exactly "positive", assume "negative" for evaluation purposes
        y_pred.append("negative")

# %%
print("Accuracy :", accuracy_score(labels, y_pred))
print("Precision:", precision_score(labels, y_pred, pos_label="positive"))
print("Recall   :", recall_score(labels, y_pred, pos_label="positive"))
print("F1-score :", f1_score(labels, y_pred, pos_label="positive"))

# %%
set(y_pred)

# %%
prompt5 = (
    "Classify the sentiment of the sentence.\n"
    "Respond with ONLY ONE WORD: positive or negative.\n\n"
    "Sentence: "
)

# %%
inputs5 = [prompt5 + s for s in sentences]

# %%
y_pred5 = []

for i, text in enumerate(inputs5):
    tokens = tokenizer(text, return_tensors="pt").to("cuda:0")

    output = model.generate(
        **tokens,
        max_new_tokens=1, # Set to 1 to force single word output
        do_sample=False
    )

    input_len = tokens["input_ids"].shape[1]
    decoded = tokenizer.decode(output[0][input_len:], skip_special_tokens=True).lower().strip() # Strict stripping

    # Print decoded output for inspection
    if i < 5: # Print for first 5 to avoid overwhelming output
        print(f"Original Sentence: {sentences[i]}\nModel Output: '{decoded}'\n") # Added quotes to clearly see output

    if decoded == "positive":
        y_pred5.append("positive")
    else: # If not exactly "positive", assume "negative" for evaluation purposes
        y_pred5.append("negative")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Original Sentence: Ever since joes has changed hands it's gotten better and better.
# Model Output:  I love the new owners.
# Sentiment: positive
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Original Sentence: There is so much room in that part of the venue
# Model Output: .
# Sentiment: positive
#
# Sentence: The food
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Original Sentence: It didn't taste watered down at all.
# Model Output: 5 stars!
# Sentiment: positive
#
# Sentence:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Original Sentence: She said she'd be back, and didn't disappear at all.
# Model Output:  I'm so happy.
# Sentiment: positive
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Original Sentence: This pharmacy is really considerate.
# Model Output:  I will come back.
# Sentiment: positive
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ...
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.

# %%
print("Accuracy :", accuracy_score(labels, y_pred5))
print("Precision:", precision_score(labels, y_pred5, pos_label="positive"))
print("Recall   :", recall_score(labels, y_pred5, pos_label="positive"))
print("F1-score :", f1_score(labels, y_pred5, pos_label="positive"))

# %%
prompt10 = (
    "Classify the sentiment of the sentence.\n"
    "Respond with ONLY ONE WORD: positive or negative.\n\n"
    "Sentence: "
)

# %%
inputs10 = [prompt10 + s for s in sentences]

# %%
y_pred10 = []

for i, text in enumerate(inputs10):
    tokens = tokenizer(text, return_tensors="pt").to("cuda:0")

    output = model.generate(
        **tokens,
        max_new_tokens=1, # Set to 1 to force single word output
        do_sample=False
    )

    input_len = tokens["input_ids"].shape[1]
    decoded = tokenizer.decode(output[0][input_len:], skip_special_tokens=True).lower().strip() # Strict stripping

    # Print decoded output for inspection
    if i < 5: # Print for first 5 to avoid overwhelming output
        print(f"Original Sentence: {sentences[i]}\nModel Output: '{decoded}'\n") # Added quotes to clearly see output

    if decoded == "positive":
        y_pred10.append("positive")
    else: # If not exactly "positive", assume "negative" for evaluation purposes
        y_pred10.append("negative")

# %%
print("Accuracy :", accuracy_score(labels, y_pred10))
print("Precision:", precision_score(labels, y_pred10, pos_label="positive"))
print("Recall   :", recall_score(labels, y_pred10, pos_label="positive"))
print("F1-score :", f1_score(labels, y_pred10, pos_label="positive"))

# %%
set(y_pred5)

# %% [markdown]
# #TASK 2

# %%
# %pip install evaluate
# %pip install bert_score
# %pip install sacrebleu

# %%
data = pd.read_csv('test_en_parallel.txt', sep='\t', header=None)
data = data[[0, 1]]
data.columns = ['NEGATIVE', 'POSITIVE']
data = data[:999]
sentences_ne = data['NEGATIVE'].values.tolist()
sentences_pos = data['POSITIVE'].values.tolist()
sentences_ne = sentences_ne[1:]
sentences_pos = sentences_pos[1:]

# %%
bleu = load('bleu')
bertscore = load('bertscore')

# %%
instruction = 'Convert the negative-sentiment sentence into a positive-sentiment sentence: '

# %%
base_prompt = (
    "You are given a sentence with negative sentiment.\n"
    "Rewrite it so that it clearly expresses positive sentiment,\n"
    "while keeping the original meaning.\n\n"
    "Sentence: "
)

# %%
generated_0 = []

for neg in sentences_ne:
    prompt = base_prompt + neg + "\nPositive version:"

    tokens = tokenizer(prompt, return_tensors="pt").to("cuda:0")

    output = model.generate(
        **tokens,
        max_new_tokens=40,
        do_sample=False
    )

    input_len = tokens["input_ids"].shape[1]
    gen_tokens = output[0][input_len:]

    decoded = tokenizer.decode(gen_tokens, skip_special_tokens=True)
    generated_0.append(decoded.strip())

# %%
bleu.compute(predictions=generated_0, references = sentences_pos)

# %%
bertscore.compute(predictions=generated_0, references=sentences_pos, model_type='microsoft/deberta-xlarge-mnli')

# %%
base_prompt5 = (
    "Rewrite the following sentence so that it expresses a positive sentiment.\n\n"
    "Sentence: The service was terrible.\nPositive version: The service was excellent.\n\n"
    "Sentence: I hated this movie.\nPositive version: I really enjoyed this movie.\n\n"
    "Sentence: The product is awful.\nPositive version: The product is great.\n\n"
    "Sentence: This was a bad experience.\nPositive version: This was a great experience.\n\n"
    "Sentence: I am disappointed.\nPositive version: I am very satisfied.\n\n"
    "Sentence: "
)

# %%
generated_5 = []

for neg in sentences_ne:
    prompt = base_prompt5 + neg + "\nPositive version:"

    tokens = tokenizer(prompt, return_tensors="pt").to("cuda:0")
    output = model.generate(**tokens, max_new_tokens=40, do_sample=False)

    input_len = tokens["input_ids"].shape[1]
    decoded = tokenizer.decode(output[0][input_len:], skip_special_tokens=True)

    generated_5.append(decoded.strip())

# %%
bleu.compute(predictions=generated_5, references = sentences_pos)

# %%
bertscore.compute(predictions=generated_5, references=sentences_pos, model_type='microsoft/deberta-xlarge-mnli')

# %%
base_prompt = (
    "Rewrite the following sentence so that it expresses a positive sentiment.\n\n"
    "Sentence: The staff was rude and unhelpful.\n"
    "Positive version: The staff was friendly and very helpful.\n\n"
    "Sentence: I did not enjoy the meal at all.\n"
    "Positive version: I really enjoyed the meal.\n\n"
    "Sentence: The movie was disappointing and boring.\n"
    "Positive version: The movie was entertaining and enjoyable.\n\n"
    "Sentence: This product feels cheap and poorly made.\n"
    "Positive version: This product feels well made and reliable.\n\n"
    "Sentence: The service took too long and was frustrating.\n"
    "Positive version: The service was quick and pleasant.\n\n"
    "Sentence: I am unhappy with my purchase.\n"
    "Positive version: I am very happy with my purchase.\n\n"
    "Sentence: The quality is below expectations.\n"
    "Positive version: The quality exceeded my expectations.\n\n"
    "Sentence: I would not recommend this to anyone.\n"
    "Positive version: I would highly recommend this to others.\n\n"
    "Sentence: The experience left me dissatisfied.\n"
    "Positive version: The experience left me satisfied.\n\n"
    "Sentence: This was a waste of time and money.\n"
    "Positive version: This was worth both the time and money.\n\n"
    "Sentence: "
)

# %%
generated_10 = []

for neg in sentences_ne:
    prompt = base_prompt + neg + "\nPositive version:"

    tokens = tokenizer(prompt, return_tensors="pt").to("cuda:0")
    output = model.generate(**tokens, max_new_tokens=40, do_sample=False)

    input_len = tokens["input_ids"].shape[1]
    decoded = tokenizer.decode(output[0][input_len:], skip_special_tokens=True)

    generated_10.append(decoded.strip())

# %%
bleu.compute(predictions=generated_10, references = sentences_pos)

# %%
bertscore.compute(predictions=generated_10, references=sentences_pos, model_type='microsoft/deberta-xlarge-mnli')

# %%
y_pred5

# %%
set(y_pred10)
